# %% [markdown]
# # Compare the model caption inference against the ground truth captions from annotations file.
# # Trained model on 97k of some 100k images of Coco_Train2017 dataset. Balance 3k kept aside as the Validation Set. Using all the 5k images of Coco_Val2017 dataset as the Test dataset.
#
# ## Encoder: Pre-trained Google Inception-v3 trained on Imagenet imported directly from Keras
# ## Decoder: Trained with the 97k data and their captions from annotations file.
#
# ## AVAILABLE data :
# ### Coco_Train2017     = has 118287 images
# ### Coco_Val2017       = has 5000   images
# ### Combined total     = 123287     images
#
# ## USED data :
# ### Coco_Train2017     = 100000  images
# ### Coco_Val2017       = 5000    images
# ### Combined total     = 105000  images
#
# ### Using only the first 100k images of Train2017 + all 5k images of Val2017
# ### Thus total data available for training = 100k + 5k = 105k
# ### Details of split of data:
# ### Training   data = 97000 images from Coco_Train2017
# ### Validation data = 3000  images from Coco_Train2017
# ### Test       data = 5000  images from Coco_Val2017
#
# ### Note: 1) Each image will have multiple captions (up to 5 as some may be discarded)
# ###       2) Not using the Coco_Test2017 dataset at all as it has no annotations json file which has the captions.
#
# ## Using this LINK: https://towardsdatascience.com/image-captioning-with-keras-teaching-computers-to-describe-pictures-c88a46a311b8
# ## Image captioning with Keras

# %%
import os
import sys
import json
import time
import datetime
import string
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
#from keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
import re
import pickle
#import itertools
import PIL
import PIL.Image

## import numpy as np
## from numpy import array
## import pandas as pd
## import matplotlib.pyplot as plt
## %matplotlib inline
## import string
## import os
## from PIL import Image
## import glob
## from pickle import dump, load
## from time import time
## from keras.preprocessing import sequence
## from keras.models import Sequential
## from keras.layers import LSTM, Embedding, TimeDistributed, Dense, RepeatVector, Activation, Flatten, Reshape, concatenate, Dropout, BatchNormalization
## from keras.optimizers import Adam, RMSprop
## from keras.layers.wrappers import Bidirectional
## from keras.layers.merge import add
## from keras.applications.inception_v3 import InceptionV3
## from keras.preprocessing import image
## from keras.models import Model
## from keras import Input, layers
## from keras import optimizers
## from keras.applications.inception_v3 import preprocess_input
## from keras.preprocessing.text import Tokenizer
## from keras.preprocessing.sequence import pad_sequences
## from keras.utils import to_categorical

# %%
#from google.colab import drive
#drive.flush_and_unmount()
#drive.mount('/content/gdrive')

# %%
## LAPTOP versions

## Weights from training till now
#OPDIR = r'../working/'

## Images locations
#IPDIR_IMGS_COCO_TRAIN = r'../input/coco-2017-dataset/coco2017/train2017/'
#IPDIR_IMGS_COCO_VAL = r'../input/coco-2017-dataset/coco2017/val2017/'

## Annotations json file location from where to pick up the captions
IPDIR_ANNO = r'/media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/coco_2017_annotations/'

## Bottleneck CNN Encoder output for all the images of TRAIN , VALIDATION and TEST DATASETS
IPDIR_IMG_ENCODINGS = r'/media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/Thesis_ImgCap_ImgEncodings_1/'

## to make deterministic - saved all the variables based on the data used to train during phase 1
## ALL SUBSEQUENT PHASES WILL RELOAD FROM THE DATA IN THIS LOCATION
IPDIR_DETERMINISTIC = r'/media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/Thesis_ImgCap_Run2_Deterministic_Info/'

## Weights from previous stage of training
## run2
#IPDIR_WEIGHTS_IN = r'/media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/Thesis_ImgCap_Weights_In_Run2/'
## run3
IPDIR_WEIGHTS_IN = r'/media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/Thesis_ImgCap_Weights_In_Run3/'

"""
## Kaggle versions

## Weights from training till now
OPDIR = r'../working/'

## Images locations
IPDIR_IMGS_COCO_TRAIN = r'../input/coco-2017-dataset/coco2017/train2017/'
IPDIR_IMGS_COCO_VAL = r'../input/coco-2017-dataset/coco2017/val2017/'

## Annotations json file location from where to pick up the captions
IPDIR_ANNO = r'../input/coco-2017-dataset/coco2017/annotations/'

## Bottleneck CNN Encoder output for all the images to be used in training
IPDIR_IMG_ENCODINGS = r'../input/thesis-imgcap-imgencodings-1/'

## to make deterministic - saved all the variables based on the data used to train during phase 1
## ALL SUBSEQUENT PHASES WILL RELOAD FROM THE DATA IN THIS LOCATION
IPDIR_DETERMINISTIC = '../input/thesis-imgcap-run2-deterministic-info/'

## Weights from previous stage of training
IPDIR_WEIGHTS_IN = r'../input/imgcap-kagg-run2-weights-in/'


#WORD_EMBEDDINGS_DIR = '/content/gdrive/My Drive/ThesisStoryGen/Data/WordEmbeddings/' #not needed as already created the embedding matrix and pickled

## Google drive versions
#OPDIR = '/content/gdrive/My Drive/ThesisStoryGen/Data/ImgCapTraining/CocoVal2017_1/'
#IPDIRIMGS = '/content/gdrive/My Drive/ThesisStoryGen/Data/coco_val2017_wget_1/val2017/'
#IPDIRANNO = '/content/gdrive/My Drive/ThesisStoryGen/Data/coco_annotations_trainval2017/'
#WORD_EMBEDDINGS_DIR = '/content/gdrive/My Drive/ThesisStoryGen/Data/WordEmbeddings/'

"""
# Out:
# "\n## Kaggle versions\n\n## Weights from training till now\nOPDIR = r'../working/'\n\n## Images locations\nIPDIR_IMGS_COCO_TRAIN = r'../input/coco-2017-dataset/coco2017/train2017/'\nIPDIR_IMGS_COCO_VAL = r'../input/coco-2017-dataset/coco2017/val2017/'\n\n## Annotations json file location from where to pick up the captions\nIPDIR_ANNO = r'../input/coco-2017-dataset/coco2017/annotations/'\n\n## Bottleneck CNN Encoder output for all the images to be used in training\nIPDIR_IMG_ENCODINGS = r'../input/thesis-imgcap-imgencodings-1/'\n\n## to make deterministic - saved all the variables based on the data used to train during phase 1\n## ALL SUBSEQUENT PHASES WILL RELOAD FROM THE DATA IN THIS LOCATION\nIPDIR_DETERMINISTIC = '../input/thesis-imgcap-run2-deterministic-info/'\n\n## Weights from previous stage of training\nIPDIR_WEIGHTS_IN = r'../input/imgcap-kagg-run2-weights-in/'\n\n\n#WORD_EMBEDDINGS_DIR = '/content/gdrive/My Drive/ThesisStoryGen/Data/WordEmbeddings/' #not needed as already created the embedding matrix and pickled\n\n## Google drive versions\n#OPDIR = '/content/gdrive/My Drive/ThesisStoryGen/Data/ImgCapTraining/CocoVal2017_1/'\n#IPDIRIMGS = '/content/gdrive/My Drive/ThesisStoryGen/Data/coco_val2017_wget_1/val2017/'\n#IPDIRANNO = '/content/gdrive/My Drive/ThesisStoryGen/Data/coco_annotations_trainval2017/'\n#WORD_EMBEDDINGS_DIR = '/content/gdrive/My Drive/ThesisStoryGen/Data/WordEmbeddings/'\n\n"

# %% [markdown]
# # Reload everything needed from pickled files created based on a certain split of Train and Validation datasets 97k:3k.
# ## Run necessary code again to check all good to proceed with Training phase:
# ## Outcome expected:
# ## 1) unique words in original vocabulary = 24323
# ## 2) unique words in culled vocab vocab_threshold = 6757
# ##    Thus, VOCAB_SIZE = 6757 + 1 = 6758
# ## 3) Embedding matrix shape should be (6758,200)

# %%
IPDIR_DETERMINISTIC
# Out:
# '/media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/Thesis_ImgCap_Run2_Deterministic_Info/'

# %%
os.listdir(IPDIR_DETERMINISTIC)
# Out:
# ['descriptions_test.pkl',
#  'descriptions_train_97000.pkl',
#  'descriptions_train_97000_startend.pkl',
#  'descriptions_train_and_val.pkl',
#  'descriptions_val_3000.pkl',
#  'embedding_matrix_6758_200.pkl',
#  'img_encodings_train_97000.pkl',
#  'img_encodings_val_3000.pkl',
#  'ixtoword_train_97000.pkl',
#  'train_imgs_keys_97000_randomSplit444.pkl',
#  'val_imgs_keys_3000_randomSplit444.pkl',
#  'wordtoix_train_97000.pkl']

# %%
## Reload all the files to make it deterministic


# variable = img_encodings_train
with open(IPDIR_DETERMINISTIC + 'img_encodings_train_97000.pkl', 'rb') as handle:
    img_encodings_train = pickle.load(handle)

# variable = img_encodings_val
with open(IPDIR_DETERMINISTIC + 'img_encodings_val_3000.pkl', 'rb') as handle:
    img_encodings_val = pickle.load(handle)

# variable = descriptions_train
with open(IPDIR_DETERMINISTIC + 'descriptions_train_97000_startend.pkl', 'rb') as handle:
    descriptions_train = pickle.load(handle)

# variable = descriptions_val
with open(IPDIR_DETERMINISTIC + 'descriptions_val_3000.pkl', 'rb') as handle:
    descriptions_val = pickle.load(handle)

# variable = train_imgs_keys
with open(IPDIR_DETERMINISTIC + 'train_imgs_keys_97000_randomSplit444.pkl', 'rb') as handle:
    train_imgs_keys = pickle.load(handle)

# variable = val_imgs_keys
with open(IPDIR_DETERMINISTIC + 'val_imgs_keys_3000_randomSplit444.pkl', 'rb') as handle:
    val_imgs_keys = pickle.load(handle)

# variable = embedding_matrix
with open(IPDIR_DETERMINISTIC + 'embedding_matrix_6758_200.pkl', 'rb') as handle:
    embedding_matrix = pickle.load(handle)

# variable = ixtoword
with open(IPDIR_DETERMINISTIC + 'ixtoword_train_97000.pkl', 'rb') as handle:
    ixtoword = pickle.load(handle)

# variable = wordtoix
with open(IPDIR_DETERMINISTIC + 'wordtoix_train_97000.pkl', 'rb') as handle:
    wordtoix = pickle.load(handle)

print(f"Reloaded it all")
# Out:
# Reloaded it all

# %%
## check the reloaded files

# %%
print(f"Encodings data:\nlen(img_encodings_train) = {len(img_encodings_train)}\t\tlen(img_encodings_val) = {len(img_encodings_val)}")
print(f"Descriptions data:\nlen(descriptions_train) = {len(descriptions_train)}\t\tlen(descriptions_val) = {len(descriptions_val)}")
print(f"\nCHECK : reloaded values = 97k for Train , 3k for Validation")
# Out:
# Encodings data:
# len(img_encodings_train) = 97000		len(img_encodings_val) = 3000
# Descriptions data:
# len(descriptions_train) = 97000		len(descriptions_val) = 3000
#
# CHECK : reloaded values = 97k for Train , 3k for Validation

# %%
## at this stage the descriptions_train already has the start and end tokens added to it
vocabulary = set()
for key in descriptions_train.keys():
    [vocabulary.update(d.split()) for d in descriptions_train[key]]
print(f"Original Vocabulary Size with all words = {len(vocabulary)}")
print(f"\nCHECK : reloaded value = 24323")
# Out:
# Original Vocabulary Size with all words = 24323
#
# CHECK : reloaded value = 24323

# %%
# Create a list of all the training captions, find the freq and retain words where the freq > threshold chosen

all_desc_in_training_samples = []
for key, val in descriptions_train.items():
    for cap in val:
        all_desc_in_training_samples.append(cap)

MIN_WORD_COUNT_THRESHOLD = 10
word_counts = {}
nsents = 0
for each_desc in all_desc_in_training_samples:
    nsents += 1
    for w in each_desc.split(' '):
        word_counts[w] = word_counts.get(w, 0) + 1

vocab_threshold = [w for w in word_counts if word_counts[w] >= MIN_WORD_COUNT_THRESHOLD]

print(f"Culled vocabulary to only retain words occurring more than threshold = {MIN_WORD_COUNT_THRESHOLD} times.\nNew vocab size , len(vocab_threshold) = {len(vocab_threshold)}")
print(f"\nCHECK : reloaded value = 6757")
# Out:
# Culled vocabulary to only retain words occurring more than threshold = 10 times.
# New vocab size , len(vocab_threshold) = 6757
#
# CHECK : reloaded value = 6757

# %%
## determine the maximum sequence length - parameter MAX_LENGTH_CAPTION used during the RNN deocder model setup

## convert a dictionary of clean descriptions to a list of descriptions
def extract_each_desc(_descriptions):
    all_desc = list()
    for key in _descriptions.keys():
        [all_desc.append(d) for d in _descriptions[key]]
    return all_desc

## find the longest description length
def find_max_length_desc(_descriptions):
    desc_sentences = extract_each_desc(_descriptions)
    return max(len(d.split()) for d in desc_sentences)

MAX_LENGTH_CAPTION = find_max_length_desc(descriptions_train)  ## will be used directly later while defining Decoder model
print(f"Max Description Length: {MAX_LENGTH_CAPTION}")
print(f"\nCHECK : reloaded value = 49")
# Out:
# Max Description Length: 49
#
# CHECK : reloaded value = 49

# %%
## the value now, as it will be used as:: VOCAB_SIZE = len(wordtoix) + 1
print(f"len(wordtoix) = {len(wordtoix)}")
print(f"\nCHECK : reloaded value = 6757")

VOCAB_SIZE = len(wordtoix) + 1
print(f"\n\nSet the   VOCAB_SIZE = len(wordtoix) + 1 = {VOCAB_SIZE}")

EMBEDDING_DIMS = 200
print(f"\n\nSet the   EMBEDDING_DIMS = {EMBEDDING_DIMS}")
# Out:
# len(wordtoix) = 6757
#
# CHECK : reloaded value = 6757
#
#
# Set the   VOCAB_SIZE = len(wordtoix) + 1 = 6758
#
#
# Set the   EMBEDDING_DIMS = 200

# %%
## see the index output by wordtoix for the start and end sequence tokens as well as some random one word
print( wordtoix.get('startseq') , wordtoix.get('endseq') , wordtoix.get('cat') )
# Out:
# 1 9 526

# %%
print(f"Shape of embedding_matrix = {embedding_matrix.shape}")
print(f"\nCHECK : reloaded shape = 6758,200")
# Out:
# Shape of embedding_matrix = (6758, 200)
#
# CHECK : reloaded shape = 6758,200

# %%
## Recheck these parameters that will define the Decoder architecture ::: EMBEDDING_DIMS , VOCAB_SIZE , MAX_LENGTH_CAPTION
print(f"SHOULD be:\nEMBEDDING_DIMS = 200 , VOCAB_SIZE = 6758 , MAX_LENGTH_CAPTION = 49")
print(f"\nThe values to be used in Decoder setup:\nEMBEDDING_DIMS = {EMBEDDING_DIMS} , VOCAB_SIZE = {VOCAB_SIZE} , MAX_LENGTH_CAPTION = {MAX_LENGTH_CAPTION}")
# Out:
# SHOULD be:
# EMBEDDING_DIMS = 200 , VOCAB_SIZE = 6758 , MAX_LENGTH_CAPTION = 49
#
# The values to be used in Decoder setup:
# EMBEDDING_DIMS = 200 , VOCAB_SIZE = 6758 , MAX_LENGTH_CAPTION = 49

# %% [markdown]
# ## Reload the Coco_Val_2017 5k image encodings from pickled file.
# ### NOTE: This is the TEST dataset I am using which has the ground truth captions for comparison against my models inference.

# %%
IPDIR_IMG_ENCODINGS
# Out:
# '/media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/Thesis_ImgCap_ImgEncodings_1/'

# %%
os.listdir(IPDIR_IMG_ENCODINGS)
# Out:
# ['train2017_subset_5k_45000_50000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_0_5000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_10000_15000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_15000_20000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_20000_25000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_25000_30000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_30000_35000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_35000_40000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_40000_45000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_50000_55000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_5000_10000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_55000_60000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_60000_65000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_65000_70000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_70000_75000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_75000_80000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_80000_85000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_85000_90000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_90000_95000_images_encoded_features_pickled_1.pkl',
#  'train2017_subset_5k_95000_100000_images_encoded_features_pickled_1.pkl',
#  'val2017_all_5k_images_encoded_features_pickled_2.pkl']

# %%
## From Val2017 images pickled files
print(f"\n\nLoading encodings for the test images")
pickled_encodings_files_val2017 = ['val2017_all_5k_images_encoded_features_pickled_2.pkl']
img_encodings_test = {}
for idx, subset_encodings_file_val2017 in enumerate(pickled_encodings_files_val2017):
    with open(IPDIR_IMG_ENCODINGS + subset_encodings_file_val2017, 'rb') as handle:
        img_encodings_test.update(pickle.load(handle))
        print(f"Loaded file num {idx+1} :: {subset_encodings_file_val2017}")
    print(f"Number of entries in img_encodings_test = {len(img_encodings_test)}")
print(f"\nFinal count img_encodings_test = {len(img_encodings_test)}. Should be = 5k.")

del pickled_encodings_files_val2017
# Out:
# Loading encodings for the test images
# Loaded file num 1 :: val2017_all_5k_images_encoded_features_pickled_2.pkl
# Number of entries in img_encodings_test = 5000
#
# Final count img_encodings_test = 5000. Should be = 5k.

# %%
## Thus "img_encodings_test" has the CNN encoder output feature encodings for all 5k images
## All these values in the dict is a numpy array of shape (2048,)

# %%
type(img_encodings_test)
# Out:
# dict

# %%
dict(list(img_encodings_test.items())[:5])
# Out:
# {'000000179765': array([0.14290808, 0.14481388, 0.30199888, ..., 0.20583029, 0.1378399 ,
#         0.05842396], dtype=float32),
#  '000000190236': array([0.13693401, 0.44517994, 0.8012962 , ..., 0.09662007, 0.5428594 ,
#         0.12551737], dtype=float32),
#  '000000331352': array([0.36297214, 0.09468681, 0.14937937, ..., 0.03184601, 0.68944204,
#         0.49036297], dtype=float32),
#  '000000517069': array([0.16364594, 0.08695374, 0.61649114, ..., 0.74132663, 0.09887794,
#         0.5194288 ], dtype=float32),
#  '000000182417': array([0.32260168, 0.7291188 , 1.62285   , ..., 0.31113395, 0.7642602 ,
#         0.21318905], dtype=float32)}

# %%
type(img_encodings_test['000000179765'])
# Out:
# numpy.ndarray

# %%
img_encodings_test['000000179765']
# Out:
# array([0.14290808, 0.14481388, 0.30199888, ..., 0.20583029, 0.1378399 ,
#        0.05842396], dtype=float32)

# %%
img_encodings_test['000000179765'].shape
# Out:
# (2048,)

# %% [markdown]
# ## Use the annotations file to load the descriptions and clean as per standard processing followed overall.

# %%
IPDIR_ANNO
# Out:
# '/media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/coco_2017_annotations/'

# %%
os.listdir(IPDIR_ANNO)
# Out:
# ['captions_train2017.json', 'captions_val2017.json']

# %%
# build the descriptions_test_dataset dict
## BUT NOTE: it is actually from the captions_val2017 dataset - which I treat as my TEST DATASET

with open(IPDIR_ANNO+'captions_val2017.json', 'r') as f:
  data = json.load(f)
  #data.keys() # dict_keys(['info', 'licenses', 'images', 'annotations'])
  #type(data['annotations']) # is a list
  #type(data['images'])      # also is a list

dfanno = pd.DataFrame(data=data['annotations'])
# dfanno.columns = Index(['image_id', 'id', 'caption'], dtype='object') 
# dfanno.dtypes =
#   image_id     int64
#   id           int64
#   caption     object
#   dtype: object

dfimages = pd.DataFrame(data=data['images'])
# dfimages.columns = Index(['license', 'file_name', 'coco_url', 'height', 'width', 'date_captured', 'flickr_url', 'id'], dtype='object')
# dfimages.dtypes =
#   license           int64
#   file_name        object
#   coco_url         object
#   height            int64
#   width             int64
#   date_captured    object
#   flickr_url       object
#   id                int64
#   dtype: object
## of above, am dropping useless columns
dfimages.drop(['license', 'coco_url', 'date_captured', 'flickr_url'], axis = 1, inplace=True)

## columns remaining in the dfs are:
# dfanno columns are      image_id , id , caption
#                         179765   , 38 ,	A black Honda motorcycle parked in front of a ...
# dfimages columns are    file_name        , height ,  width , id
#                         000000397133.jpg , 427    ,  640   , 397133

## the captions are not ordered for each image and seem to be randomly placed

dfanno.head(3)
# Out:
#    image_id   id                                            caption
# 0    179765   38  A black Honda motorcycle parked in front of a ...
# 1    179765  182      A Honda motorcycle parked in a grass driveway
# 2    190236  401  An office cubicle with four different types of...

# %%
## marrying the "annotations" and the "images" keys info together into dfanno
## the file_name column has the actual image name from the "image" key section
dfanno = dfanno.merge(dfimages, how="inner", left_on='image_id', right_on='id')
dfanno.drop(['height', 'width', 'id_y'], axis = 1, inplace=True)
dfanno.rename(columns={'id_x':'id'}, inplace=True)
dfanno.head(3)
# Out:
#    image_id   id                                            caption  \
# 0    179765   38  A black Honda motorcycle parked in front of a ...
# 1    179765  182      A Honda motorcycle parked in a grass driveway
# 2    179765  479  A black Honda motorcycle with a dark burgundy ...
#
#           file_name
# 0  000000179765.jpg
# 1  000000179765.jpg
# 2  000000179765.jpg

# %%
## Mapping image with captions using dictionary

def create_descriptions_dictionary(_dfin):
    descriptions = {}
    for row in _dfin.itertuples():
      rowdict = row._asdict()
      img_filename = rowdict['file_name'].split('.')[0] # drop the .jpg part
      img_caption = rowdict['caption']
      if(img_filename not in descriptions):
        descriptions[img_filename] = [img_caption]
      else:
        descriptions[img_filename].append(img_caption)
    return descriptions

descriptions_test = create_descriptions_dictionary(dfanno)
print(f"len(descriptions_test) = {len(descriptions_test)}")

del dfanno
# Out:
# len(descriptions_test) = 5000

# %% [markdown]
# ## Clean the description for test dataset

# %%
dict(list(descriptions_test.items())[:2])
# Out:
# {'000000179765': ['A black Honda motorcycle parked in front of a garage.',
#   'A Honda motorcycle parked in a grass driveway',
#   'A black Honda motorcycle with a dark burgundy seat.',
#   'Ma motorcycle parked on the gravel in front of a garage',
#   'A motorcycle with its brake extended standing outside'],
#  '000000190236': ['An office cubicle with four different types of computers.',
#   'The home office space seems to be very cluttered.',
#   'an office with desk computer and chair and laptop.',
#   'Office setting with a lot of computer screens.',
#   'A desk and chair in an office cubicle.']}

# %%
## example of caption with accidental newline \n in the caption
descriptions_test['000000482917']
# Out:
# ['A dog sitting between its masters feet on a footstool watching tv\n',
#  'A dog between the feet of a person looking at a TV.',
#  'A dog and a person are watching television together.',
#  'A person is sitting with their dog watching tv.',
#  'A man relaxing at home, watching television with his dog.']

# %%
# prepare translation table for removing punctuation
## string.punctuation  gives   '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~' and will take care of all these characters being made into a space
tran_table = str.maketrans(string.punctuation, ' ' * len(string.punctuation))
for key, desc_list in descriptions_test.items():
    for idx in range(len(desc_list)):
        desc = desc_list[idx]
        # replace all punctuation with space in description before tokenizing
        desc = desc.translate(tran_table)
        # tokenize
        desc = desc.split()
        # convert to lower case
        desc = [word.lower() for word in desc]
        # remove hanging 's' and 'a'
        desc = [word for word in desc if len(word)>1]
        # remove any non-alphabetic tokens
        desc = [word for word in desc if word.isalpha()]
        # overwrite with cleaned description
        desc_list[idx] =  ' '.join(desc)

# %%
## example of caption with accidental newline \n in the caption  -- POST CLEANUP
descriptions_test['000000482917']
# Out:
# ['dog sitting between its masters feet on footstool watching tv',
#  'dog between the feet of person looking at tv',
#  'dog and person are watching television together',
#  'person is sitting with their dog watching tv',
#  'man relaxing at home watching television with his dog']

# %%
## now the cleaned descriptions are ready in "descriptions_test" file.
## Note: No need to add the startseq and endseq tokens as I will remove that from the inference before comparison

# %% [markdown]
# ### get an idea of the length of GT captions in cleaned descriptions

# %%
[gt_cap for desc in descriptions_test.values() for gt_cap in desc][:8]
# Out:
# ['black honda motorcycle parked in front of garage',
#  'honda motorcycle parked in grass driveway',
#  'black honda motorcycle with dark burgundy seat',
#  'ma motorcycle parked on the gravel in front of garage',
#  'motorcycle with its brake extended standing outside',
#  'an office cubicle with four different types of computers',
#  'the home office space seems to be very cluttered',
#  'an office with desk computer and chair and laptop']

# %%
df = pd.DataFrame(data=[gt_cap for desc in descriptions_test.values() for gt_cap in desc], columns=['sent'])
df['caplen'] = df['sent'].str.split().apply(len)
#df['sent'][df['caplen'] == MAX_LENGTH_CAPTION]
df[:8]
# Out:
#                                                 sent  caplen
# 0   black honda motorcycle parked in front of garage       8
# 1          honda motorcycle parked in grass driveway       6
# 2     black honda motorcycle with dark burgundy seat       7
# 3  ma motorcycle parked on the gravel in front of...      10
# 4  motorcycle with its brake extended standing ou...       7
# 5  an office cubicle with four different types of...       9
# 6   the home office space seems to be very cluttered       9
# 7  an office with desk computer and chair and laptop       9

# %%
## see counts of descriptions with the LONGEST lengths
## we see only one caption has the maximum length
## NOTE: no startseq and endseq tokens present
countdf = df['caplen'].value_counts()
countdf.sort_index(inplace=True, ascending=False)
countdf.head(15)
# Out:
# 45     1
# 42     1
# 35     1
# 34     1
# 33     1
# 32     2
# 30     1
# 29     1
# 28     2
# 27     3
# 26     1
# 25     6
# 24     6
# 23     7
# 22    11
# Name: caplen, dtype: int64

# %%
## see counts of descriptions with the SHORTEST lengths
## NOTE: no startseq and endseq tokens present
countdf = df['caplen'].value_counts()
countdf.sort_index(inplace=True, ascending=True)
countdf.head(15)
# Out:
# 5      160
# 6     1971
# 7     4873
# 8     6005
# 9     4864
# 10    3118
# 11    1764
# 12     958
# 13     512
# 14     306
# 15     151
# 16     117
# 17      61
# 18      44
# 19      26
# Name: caplen, dtype: int64

# %%
## maximum lenght of description in Test data is 45 without extra tokens, else 47 with startseq and endseq inserted
## But my trained model has max caption length of 49 including the extra tokens for startseq and endseq
df['caplen'].max()
# Out:
# 45

# %%
## see the description with longest length = 45
df.loc[df['caplen'] == df['caplen'].max()]
# Out:
#                                                     sent  caplen
# 15996  large square concrete wall which shows people ...      45

# %%
del df, countdf

# %% [markdown]
# ## ALWAYS - Define the RNN Decoder model
# ## Reload ALL weights from previous training point. Then freeze ONLY the embedding layer as before. Thus, the embedding layer will continue to use the GloVe-200 embeddings matrix weights that were first set during Training Phase 1 setup.
#
#
# ### About Keras Emebedding layer
# ###
# #### Default initializing of this layer: https://keras.io/api/layers/core_layers/embedding/
# ######tf.keras.layers.Embedding(
# ######    input_dim, output_dim,
# ######    embeddings_initializer="uniform",
# ######    embeddings_regularizer=None,
# ######    activity_regularizer=None,
# ######    embeddings_constraint=None,
# ######    mask_zero=False,
# ######    input_length=None,
# ######    **kwargs
# ######)

# %%
IPDIR_WEIGHTS_IN
# Out:
# '/media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/Thesis_ImgCap_Weights_In_Run3/'

# %%
os.listdir(IPDIR_WEIGHTS_IN)
# Out:
# ['Decoder_Run_3_Wt_ep_1.h5',
#  'Decoder_Run_3_Wt_ep_10.h5',
#  'Decoder_Run_3_Wt_ep_11.h5',
#  'Decoder_Run_3_Wt_ep_12.h5',
#  'Decoder_Run_3_Wt_ep_13.h5',
#  'Decoder_Run_3_Wt_ep_14.h5',
#  'Decoder_Run_3_Wt_ep_15.h5',
#  'Decoder_Run_3_Wt_ep_16.h5',
#  'Decoder_Run_3_Wt_ep_17.h5',
#  'Decoder_Run_3_Wt_ep_18.h5',
#  'Decoder_Run_3_Wt_ep_19.h5',
#  'Decoder_Run_3_Wt_ep_2.h5',
#  'Decoder_Run_3_Wt_ep_3.h5',
#  'Decoder_Run_3_Wt_ep_4.h5',
#  'Decoder_Run_3_Wt_ep_5.h5',
#  'Decoder_Run_3_Wt_ep_6.h5',
#  'Decoder_Run_3_Wt_ep_7.h5',
#  'Decoder_Run_3_Wt_ep_8.h5',
#  'Decoder_Run_3_Wt_ep_9.h5']

# %% [markdown]
# ## IMPORTANT - SPECIFY CORRECT WEIGHTS FILE TO LOAD FROM

# %%
RELOAD_WEIGHTS_FILE_NAME = r'Decoder_Run_3_Wt_ep_18.h5'

# %%
RELOAD_WEIGHTS_FILE_PATH = IPDIR_WEIGHTS_IN + RELOAD_WEIGHTS_FILE_NAME
print(f"Will reload this file = {RELOAD_WEIGHTS_FILE_PATH}")
print(f"Verfiy the weights in file exists : Check value is True = {os.path.exists(RELOAD_WEIGHTS_FILE_PATH) and os.path.isfile(RELOAD_WEIGHTS_FILE_PATH)}")
# Out:
# Will reload this file = /media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/Thesis_ImgCap_Weights_In_Run3/Decoder_Run_3_Wt_ep_18.h5
# Verfiy the weights in file exists : Check value is True = True

# %%
def get_model_parameter_counts(_model):
    total_params = _model.count_params()
    total_trainable_params = int(np.sum([np.prod(v.get_shape().as_list()) for v in _model.trainable_variables]))
    total_non_trainable_params = int(np.sum([np.prod(v.get_shape().as_list()) for v in _model.non_trainable_variables]))
    #print(f"Total params = {total_decoder_params}\t Trainable total = {total_decoder_trainable_params}\t Non-trainable total = {total_decoder_non_trainable_params}")
    return total_params, total_trainable_params, total_non_trainable_params

def reload_rnn_decoder_for_inference(_saved_weights_file, _EMBEDDING_DIMS, _VOCAB_SIZE, _MAX_LENGTH_CAPTION):
    if os.path.exists(_saved_weights_file) and os.path.isfile(_saved_weights_file):
        ## Decoder Model defining
        
        ## parameters to define model - sent during function call
        #EMBEDDING_DIMS is initialised earlier while creating embedding matrix
        #VOCAB_SIZE is initialised earlier
        #MAX_LENGTH_CAPTION is initialised earlier
        
        inputs1 = keras.Input(shape=(2048,))
        fe1 = keras.layers.Dropout(0.5)(inputs1)
        fe2 = keras.layers.Dense(256, activation='relu')(fe1)
        
        # partial caption sequence model
        inputs2 = keras.Input(shape=(_MAX_LENGTH_CAPTION,))
        se1 = keras.layers.Embedding(_VOCAB_SIZE, _EMBEDDING_DIMS, mask_zero=True)(inputs2)
        se2 = keras.layers.Dropout(0.5)(se1)
        se3 = keras.layers.LSTM(256)(se2)
        
        # decoder (feed forward) model
        decoder1 = keras.layers.add([fe2, se3])
        decoder2 = keras.layers.Dense(256, activation='relu')(decoder1)
        outputs = keras.layers.Dense(_VOCAB_SIZE, activation='softmax')(decoder2)
        
        # merge the two input models
        reloaded_rnn_decoder_model = keras.models.Model(inputs=[inputs1, inputs2], outputs=outputs)
        
        total_p, trainable_p, non_trainable_p = get_model_parameter_counts(reloaded_rnn_decoder_model)
        print(f"\nCreated RNN Decoder model defined with these paramenters:\nEMBEDDING_DIMS = {_EMBEDDING_DIMS} , VOCAB_SIZE = {_VOCAB_SIZE} , MAX_LENGTH_CAPTION = {_MAX_LENGTH_CAPTION}")
        print(f"\nBEFORE LOADING WEIGHTS AND FREEZING, parameter counts:\nTotal parameters = {total_p} , Trainable parameter = {trainable_p} , Non-trainable parameters = {non_trainable_p}")
        
        
        print(f"\nAttempting to load weights...\n")
        
        ## load the weights
        reloaded_rnn_decoder_model.load_weights(_saved_weights_file)
        print(f"SUCCESS - Reloaded weights from :: {_saved_weights_file}")
        
        ## freeze the embeddings layer weights so they are non-trainable
        reloaded_rnn_decoder_model.trainable = False
        print(f"\nFrozen all layers as this is only for inference and not for training.")
        
        total_p, trainable_p, non_trainable_p = get_model_parameter_counts(reloaded_rnn_decoder_model)
        print(f"\nAFTER FREEZING, parameter counts:\nTotal parameters = {total_p} , Trainable parameter = {trainable_p} , Non-trainable parameters = {non_trainable_p}")
        
        return reloaded_rnn_decoder_model
    else:
        print(f"\nERROR reloading weights. Check weights file exists here = {_saved_weights_file} ;\nOR model setup parameters incompatible with the saved weights file given.")
        return None

# %%
print(f"The values to be used in Decoder setup:\nEMBEDDING_DIMS = {EMBEDDING_DIMS} , VOCAB_SIZE = {VOCAB_SIZE} , MAX_LENGTH_CAPTION = {MAX_LENGTH_CAPTION}")
print(f"Weights to be reloaded from here:\n{RELOAD_WEIGHTS_FILE_PATH}")
# Out:
# The values to be used in Decoder setup:
# EMBEDDING_DIMS = 200 , VOCAB_SIZE = 6758 , MAX_LENGTH_CAPTION = 49
# Weights to be reloaded from here:
# /media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/Thesis_ImgCap_Weights_In_Run3/Decoder_Run_3_Wt_ep_18.h5

# %%
reloaded_RNN_decoder = reload_rnn_decoder_for_inference(RELOAD_WEIGHTS_FILE_PATH, EMBEDDING_DIMS, VOCAB_SIZE, MAX_LENGTH_CAPTION)
if reloaded_RNN_decoder is None:
    print(f"FATAL ERROR setting up Decoder")
else:
    print(f"\n{type(reloaded_RNN_decoder)}")
# Out:
# Created RNN Decoder model defined with these paramenters:
# EMBEDDING_DIMS = 200 , VOCAB_SIZE = 6758 , MAX_LENGTH_CAPTION = 49
#
# BEFORE LOADING WEIGHTS AND FREEZING, parameter counts:
# Total parameters = 4146710 , Trainable parameter = 4146710 , Non-trainable parameters = 0
#
# Attempting to load weights...
#
# SUCCESS - Reloaded weights from :: /media/rohit/DATA/EverythingD/01SRH-BDBA Acads/Thesis/StoryGenerator/Code/ModelsRuns/ImgCap/SavedData/Thesis_ImgCap_Weights_In_Run3/Decoder_Run_3_Wt_ep_18.h5
#
# Frozen all layers as this is only for inference and not for training.
#
# AFTER FREEZING, parameter counts:
# Total parameters = 4146710 , Trainable parameter = 0 , Non-trainable parameters = 4146710
#
# <class 'tensorflow.python.keras.engine.training.Model'>

# %%
## Output of command:  model_RNN_decoder.summary() AFTER FREEZING THE EMBEDDINGS WEIGHTS
## NOTE the count of Trainable params has REDUCED
reloaded_RNN_decoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 49)]         0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 2048)]       0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 49, 200)      1351600     input_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           input_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 49, 200)      0           embedding[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          524544      dropout[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 256)          467968      dropout_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256)          0           dense[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          65792       add[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 6758)         1736806     dense_1[0][0]
# ==================================================================================================
# Total params: 4,146,710
# Trainable params: 0
# Non-trainable params: 4,146,710
# __________________________________________________________________________________________________

# %%
## Output of command:  model_RNN_decoder.summary() AFTER FREEZING EVERYTHING
## NOTE the count of Trainable params is ZERO now

#Model: "functional_5"
#__________________________________________________________________________________________________
#Layer (type)                    Output Shape         Param #     Connected to                     
#==================================================================================================
#input_6 (InputLayer)            [(None, 49)]         0                                            
#__________________________________________________________________________________________________
#input_5 (InputLayer)            [(None, 2048)]       0                                            
#__________________________________________________________________________________________________
#embedding_2 (Embedding)         (None, 49, 200)      1351600     input_6[0][0]                    
#__________________________________________________________________________________________________
#dropout_4 (Dropout)             (None, 2048)         0           input_5[0][0]                    
#__________________________________________________________________________________________________
#dropout_5 (Dropout)             (None, 49, 200)      0           embedding_2[0][0]                
#__________________________________________________________________________________________________
#dense_6 (Dense)                 (None, 256)          524544      dropout_4[0][0]                  
#__________________________________________________________________________________________________
#lstm_2 (LSTM)                   (None, 256)          467968      dropout_5[0][0]                  
#__________________________________________________________________________________________________
#add_2 (Add)                     (None, 256)          0           dense_6[0][0]                    
#                                                                 lstm_2[0][0]                     
#__________________________________________________________________________________________________
#dense_7 (Dense)                 (None, 256)          65792       add_2[0][0]                      
#__________________________________________________________________________________________________
#dense_8 (Dense)                 (None, 6758)         1736806     dense_7[0][0]                    
#==================================================================================================
#Total params: 4,146,710
#Trainable params: 0
#Non-trainable params: 4,146,710
#__________________________________________________________________________________________________

# %% [markdown]
# # Perform inference on all the 5k images of the TEST DATASET (coco_val2017 data)
# ## NOTE: For this data, the image encodings are already available so no need to start with the jpg image i.e. the CNN Encoder is not required at all.
#
# ### descriptions_test dict has array of cleaned descriptions with image (without jpg) as key
# ### img_encodings_test has the image encodings availabe with image (without jpg) as key

# %%
print(f"{type(descriptions_test)}")
print(f"{type(img_encodings_test)}")
## verify the key match
print(f"{ descriptions_test.keys() == img_encodings_test.keys() }")
# Out:
# <class 'dict'>
# <class 'dict'>
# True

# %%
img_encodings_test['000000179765'].shape
# Out:
# (2048,)

# %%
## functions to actually do the inference

## per link: https://yashk2810.github.io/Image-Captioning-using-InceptionV3-and-Beam-Search/
##     "Image Captioning using InceptionV3 and Beam Search"
def beamSearch(_decoder_model, _img_encoding, _max_length, _wordtoix = None, _ixtoword = None, _beam_width=3):
    start = [_wordtoix["startseq"]]
    
    # start_word[0][0] = index of the starting word
    # start_word[0][1] = probability of the word predicted
    start_word = [[start, 0.0]]
    
    while len(start_word[0][0]) < _max_length:
        temp = []
        for s in start_word:
            #par_caps = keras.preprocessing.sequence.pad_sequences([s[0]], maxlen=_max_length, padding='post')
            sequence = keras.preprocessing.sequence.pad_sequences([s[0]], maxlen=_max_length, padding='post')
            preds = _decoder_model.predict([_img_encoding,sequence], verbose=0)
            #print(f"\n\ntype(preds) = {type(preds)}\npreds=\n{preds}\n\n")
            
            # Getting the top <_beam_width>(n) predictions
            word_preds = np.argsort(preds[0])[-_beam_width:]
            
            # creating a new list so as to put them via the model again
            for w in word_preds:
                next_cap, prob = s[0][:], s[1]
                next_cap.append(w)
                prob += preds[0][w]
                temp.append([next_cap, prob])
                    
        start_word = temp
        # Sorting according to the probabilities
        start_word = sorted(start_word, reverse=False, key=lambda l: l[1])
        # Getting the top words
        start_word = start_word[-_beam_width:]
    
    start_word = start_word[-1][0]
    intermediate_caption = [_ixtoword[i] for i in start_word]

    final_caption = []
    """
    for i in intermediate_caption:
        if i != "endseq":
            final_caption.append(i)
        else:
            break
    """
    for i in intermediate_caption:
        final_caption.append(i)
        if i == "endseq":
            break
    
    final_caption = ' '.join(final_caption) ## retain the startseq and endseq token words
    return final_caption

def greedySearch(_decoder_model, _img_encoding, _max_length, _wordtoix = None, _ixtoword = None):
    wordtoix = _wordtoix
    ixtoword = _ixtoword
    in_text = 'startseq'
    for i in range(_max_length):
        sequence = [ wordtoix[w] for w in in_text.split() if w in wordtoix ]
        sequence = keras.preprocessing.sequence.pad_sequences([sequence], maxlen=_max_length)
        yhat = _decoder_model.predict([_img_encoding,sequence], verbose=0)
        yhat = np.argmax(yhat)
        word = ixtoword[yhat]
        in_text += ' ' + word
        if word == 'endseq':
            break
    caption_out = in_text.split()
    #caption_out = caption_out[1:-1]  ## drop the startseq and endseq words at either end
    caption_out = ' '.join(caption_out)
    return caption_out

def do_inference_one_image_on_encoding_GREEDY(_img_encoding_4m_pkl, _MAX_LENGTH_CAPTION, _model_RNN_decoder, _wordtoix, _ixtoword):
    ## convert the shape from (2048,) to (1,2048) that the Decoder model expects
    img_encoding_for_inference = _img_encoding_4m_pkl.reshape((1,2048))
    
    ## get the prediction caption using greedy search
    predicted_caption = greedySearch(_model_RNN_decoder, img_encoding_for_inference, _MAX_LENGTH_CAPTION, _wordtoix, _ixtoword)
    return predicted_caption

def do_inference_one_image_on_encoding_BEAMSEARCH(_img_encoding_4m_pkl, _MAX_LENGTH_CAPTION, _model_RNN_decoder, _wordtoix, _ixtoword, _beam_width):
    ## convert the shape from (2048,) to (1,2048) that the Decoder model expects
    img_encoding_for_inference = _img_encoding_4m_pkl.reshape((1,2048))
    
    ## get the prediction caption using greedy search
    predicted_caption = beamSearch(_model_RNN_decoder, img_encoding_for_inference, _MAX_LENGTH_CAPTION, _wordtoix, _ixtoword, _beam_width)
    return predicted_caption

# %%
MAX_LENGTH_CAPTION
# Out:
# 49

# %% [markdown]
# ## Beam Search version

# %%
## BEAM SEARCH   BEAM SEARCH    BEAM SEARCH     BEAM SEARCH
## use the encodings and get inferences - BEAM SEARCH
BEAM_WIDTH = 5
comparison_dict = {}  ## key will be the image name, values will be inference caption and the cleaned descriptions
total_to_infer = len(img_encodings_test)
i = 0

start_timestamp = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
start_tick = time.time()

print(f"\n\nStarted at = {start_timestamp}\n")

for key_img, img_pre_encoding_from_pkl in img_encodings_test.items():
    if i % 50 == 0:
        print(f"Processing {i+1} of {total_to_infer}")
    ## get the inference caption
    predicted_caption = do_inference_one_image_on_encoding_BEAMSEARCH(img_pre_encoding_from_pkl, MAX_LENGTH_CAPTION, reloaded_RNN_decoder, wordtoix, ixtoword, BEAM_WIDTH)
    if i % 100 == 0:
        print(f"{i+1} cap =\n{predicted_caption}")
    ## strip off the startseq and endseq - note that startseq is ALWAYS present as the first word, but the endseq MAY NOT ALWAYS be at the end
    predicted_caption = predicted_caption.split(' ')
    if predicted_caption[-1] == 'endseq':
        predicted_caption = ' '.join(predicted_caption[1:-1]) ## remove both ends
    else:
        predicted_caption = ' '.join(predicted_caption[1:])   ## remove only startseq
    ## update the comparison dict
    comparison_dict.update( { key_img : [predicted_caption , descriptions_test[key_img] ] } )
    i += 1
    #if i>2:
    #    break

end_timestamp = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
end_tick = time.time()

print(f"\n\nEnded at = {end_timestamp}\nTime taken = {end_tick - start_tick} seconds\n")
print(f"Done")
# Out:
# Started at = 2020-10-08 12:29:46
#
# Processing 1 of 5000
# 1 cap =
# startseq motorcycle is parked on the side of the road endseq
# Processing 51 of 5000
# Processing 101 of 5000
# 101 cap =
# startseq tall building with clock on the top of it endseq
# Processing 151 of 5000
# Processing 201 of 5000
# 201 cap =
# startseq living room filled with lots of furniture and flat screen tv endseq
# Processing 251 of 5000
# Processing 301 of 5000
# 301 cap =
# startseq black and white photo of an old stove endseq
# Processing 351 of 5000
# Processing 401 of 5000
# 401 cap =
# startseq large jetliner flying through cloudy sky endseq
# Processing 451 of 5000
# Processing 501 of 5000
# 501 cap =
# startseq man standing in kitchen next to sink endseq
# Processing 551 of 5000
# Processing 601 of 5000
# 601 cap =
# startseq black and white photo of dog laying on bed endseq
# Processing 651 of 5000
# Processing 701 of 5000
# 701 cap =
# startseq white sink and mirror in bathroom endseq
# Processing 751 of 5000
# Processing 801 of 5000
# 801 cap =
# startseq small propeller plane sitting on top of field endseq
# Processing 851 of 5000
# Processing 901 of 5000
# 901 cap =
# startseq couple of giraffe standing next to each other next to tree endseq
# Processing 951 of 5000
# Processing 1001 of 5000
# 1001 cap =
# startseq red fire hydrant sitting on the side of road endseq
# Processing 1051 of 5000
# Processing 1101 of 5000
# 1101 cap =
# startseq group of people standing next to fire truck endseq
# Processing 1151 of 5000
# Processing 1201 of 5000
# 1201 cap =
# startseq small bird sitting on top of tree branch endseq
# Processing 1251 of 5000
# Processing 1301 of 5000
# 1301 cap =
# startseq group of people standing on top of lush green field endseq
# Processing 1351 of 5000
# Processing 1401 of 5000
# 1401 cap =
# startseq wooden bench sitting on top of wooden bench endseq
# Processing 1451 of 5000
# Processing 1501 of 5000
# 1501 cap =
# startseq group of people sitting on top of lush green hillside endseq
# Processing 1551 of 5000
# Processing 1601 of 5000
# 1601 cap =
# startseq herd of sheep standing next to each other on lush green field endseq
# Processing 1651 of 5000
# Processing 1701 of 5000
# 1701 cap =
# startseq small boat sitting on top of body of water endseq
# Processing 1751 of 5000
# Processing 1801 of 5000
# 1801 cap =
# startseq train traveling down train tracks next to forest endseq
# Processing 1851 of 5000
# Processing 1901 of 5000
# 1901 cap =
# startseq large brown bear sitting on top of pile of rocks endseq
# Processing 1951 of 5000
# Processing 2001 of 5000
# 2001 cap =
# startseq close up of cat laying on top of bed endseq
# Processing 2051 of 5000
# Processing 2101 of 5000
# 2101 cap =
# startseq truck parked in the snow next to building endseq
# Processing 2151 of 5000
# Processing 2201 of 5000
# 2201 cap =
# startseq group of young men playing game of frisbee endseq
# Processing 2251 of 5000
# Processing 2301 of 5000
# 2301 cap =
# startseq black and white photo of man sitting on top of toilet endseq
# Processing 2351 of 5000
# Processing 2401 of 5000
# 2401 cap =
# startseq semi truck parked on the side of the road next to another truck endseq
# Processing 2451 of 5000
# Processing 2501 of 5000
# 2501 cap =
# startseq close up of bowl of food with broccoli endseq
# Processing 2551 of 5000
# Processing 2601 of 5000
# 2601 cap =
# startseq the dog is sitting on top of the bed endseq
# Processing 2651 of 5000
# Processing 2701 of 5000
# 2701 cap =
# startseq person riding skate board at skate park endseq
# Processing 2751 of 5000
# Processing 2801 of 5000
# 2801 cap =
# startseq group of baseball players standing on top of field endseq
# Processing 2851 of 5000
# Processing 2901 of 5000
# 2901 cap =
# startseq group of baseball players standing on top of field endseq
# Processing 2951 of 5000
# Processing 3001 of 5000
# 3001 cap =
# startseq an assortment of fruits and vegetables at market endseq
# Processing 3051 of 5000
# Processing 3101 of 5000
# 3101 cap =
# startseq woman walking down street holding an umbrella endseq
# Processing 3151 of 5000
# Processing 3201 of 5000
# 3201 cap =
# startseq white dog laying on top of grass covered field endseq
# Processing 3251 of 5000
# Processing 3301 of 5000
# 3301 cap =
# startseq living room filled with furniture and flat screen tv endseq
# Processing 3351 of 5000
# Processing 3401 of 5000
# 3401 cap =
# startseq man standing on top of sandy beach next to boat endseq
# Processing 3451 of 5000
# Processing 3501 of 5000
# 3501 cap =
# startseq group of people riding skis on top of snow covered slope endseq
# Processing 3551 of 5000
# Processing 3601 of 5000
# 3601 cap =
# startseq man with hat is holding banana endseq
# Processing 3651 of 5000
# Processing 3701 of 5000
# 3701 cap =
# startseq group of people standing next to each other on lush green field endseq
# Processing 3751 of 5000
# Processing 3801 of 5000
# 3801 cap =
# startseq the man is taking picture of himself on his cell phone endseq
# Processing 3851 of 5000
# Processing 3901 of 5000
# 3901 cap =
# startseq birthday cake with lit candles on top of it endseq
# Processing 3951 of 5000
# Processing 4001 of 5000
# 4001 cap =
# startseq woman laying in bed next to white dog endseq
# Processing 4051 of 5000
# Processing 4101 of 5000
# 4101 cap =
# startseq man standing on tennis court holding racquet endseq
# Processing 4151 of 5000
# Processing 4201 of 5000
# 4201 cap =
# startseq there is remote control sitting on top of table endseq
# Processing 4251 of 5000
# Processing 4301 of 5000
# 4301 cap =
# startseq male tennis player getting ready to hit the ball endseq
# Processing 4351 of 5000
# Processing 4401 of 5000
# 4401 cap =
# startseq an image of cake that is sitting on table endseq
# Processing 4451 of 5000
# Processing 4501 of 5000
# 4501 cap =
# startseq group of people standing on top of sandy beach next to the ocean endseq
# Processing 4551 of 5000
# Processing 4601 of 5000
# 4601 cap =
# startseq woman standing in kitchen preparing food endseq
# Processing 4651 of 5000
# Processing 4701 of 5000
# 4701 cap =
# startseq there is no image here to provide caption for endseq
# Processing 4751 of 5000
# Processing 4801 of 5000
# 4801 cap =
# startseq the man is talking on his cell phone endseq
# Processing 4851 of 5000
# Processing 4901 of 5000
# 4901 cap =
# startseq vase filled with flowers sitting on top of wooden table endseq
# Processing 4951 of 5000
#
#
# Ended at = 2020-10-09 18:12:41
# Time taken = 106974.32549738884 seconds
#
# Done

# %%
comparison_dict
# Out:
# {'000000179765': ['motorcycle is parked on the side of the road',
#   ['black honda motorcycle parked in front of garage',
#    'honda motorcycle parked in grass driveway',
#    'black honda motorcycle with dark burgundy seat',
#    'ma motorcycle parked on the gravel in front of garage',
#    'motorcycle with its brake extended standing outside']],
#  '000000190236': ['desk with computer monitor and monitor',
#   ['an office cubicle with four different types of computers',
#    'the home office space seems to be very cluttered',
#    'an office with desk computer and chair and laptop',
#    'office setting with lot of computer screens',
#    'desk and chair in an office cubicle']],
#  '000000331352': ['white toilet sitting next to bath tub',
#   ['small closed toilet in cramped space',
#    'tan toilet and sink combination in small room',
#    'this is an advanced toilet with sink and control panel',
#    'close up picture of toilet with fountain',
#    'off white toilet with faucet and controls']],
#  '000000517069': ['man and woman sitting on park bench',
#   ['two women waiting at bench next to street',
#    'woman sitting on bench and woman standing waiting for the bus',
#    'woman sitting on bench in the middle of the city',
#    'woman sitting on bench and woman standing behind the bench at bus stop',
#    'woman and another woman waiting at stop']],
#  '000000182417': ['white plate topped with plates of food',
#   ['beautiful dessert waiting to be shared by two people',
#    'there is piece of cake on plate with decorations on it',
#    'creamy cheesecake dessert with whip cream and caramel',
#    'an extravagant dessert on plate overlooking the water',
#    'this is picture of an extremely fancy desert']],
#  '000000046378': ['black and white photo of two sheep in field',
#   ['cat eating bird it has caught',
#    'white cat caught bird outside on patio',
#    'grey house cat devours song bird on door step',
#    'long haired cat eating dead bird',
#    'cat eating dead bird on the ground']],
#  '000000093437': ['the man is holding hot dog in his mouth',
#   ['shot of an elderly man inside kitchen',
#    'an old man is wearing an odd hat',
#    'an older man is wearing funny hat in his dining room',
#    'man in jacket and hat looks at the camera',
#    'an old man standing in kitchen posing for picture']],
#  '000000172330': ['black and white photo of cat on motorcycle',
#   ['cat in between two cars in parking lot',
#    'cat stands between two parked cars on grassy sidewalk',
#    'cat at attention between two parked cars',
#    'grey and white cat watches from between parked cars',
#    'grey and white cat standing in the grass in parking lot']],
#  '000000472678': ['desktop computer sitting on top of wooden desk',
#   ['an office cubicle with multiple computers in it',
#    'an office desk with two flat panel monitors',
#    'an office desk with two computer screens books diagrams and phone on it',
#    'two computer monitors are placed beside each other on desk',
#    'desk with two monitors depicting security cameras']],
#  '000000314251': ['group of people riding on the back of red motorcycle',
#   ['parade of motorcycles is going through group of tall trees',
#    'group of motorcyclists drive down tree lined street',
#    'group of motorcycles down long street filled with trees on either side',
#    'group of people riding mopeds through park',
#    'group of scooters rides down street']],
#  '000000223747': ['person laying on bed with remote control',
#   ['man sleeping with his cat next to him',
#    'young man and his cute cat enjoy nap together',
#    'man is sleeping with his head on pillow',
#    'man sleeping in his bedroom next to cat',
#    'man sleeping next to cat on bed']],
#  '000000109976': ['white refrigerator freezer sitting next to microwave',
#   ['an all white kitchen with an electric stovetop',
#    'white stove sits between two small counter tops',
#    'close up of white kitchen setup with coffee maker on counter',
#    'white stove and cabinet inside kitchen',
#    'this is small kitchen with white cabinets and appliances']],
#  '000000012667': ['person holding pair of scissors in front of mirror',
#   ['the telephone has banana where the receiver should be',
#    'banana replacing the phone on an answering machine',
#    'phone with banana where the receiver should be',
#    'telephone has it receiver replaced with banana',
#    'banana placed on phone on table']],
#  '000000482917': ['black and white photo of dog laying on bed',
#   ['dog sitting between its masters feet on footstool watching tv',
#    'dog between the feet of person looking at tv',
#    'dog and person are watching television together',
#    'person is sitting with their dog watching tv',
#    'man relaxing at home watching television with his dog']],
#  '000000534605': ['group of people riding on the back of motorcycle',
#   ['man in motorcycle leathers standing in front of group of bikes',
#    'bikers dressed in their gear standing near their motorcycles',
#    'group of men stand next to their bicycles',
#    'three men standing around their motorcycles in parking lot',
#    'group of three motorcyclists standing in front of their motorcycles']],
#  '000000289393': ['the dog is looking out the window of the window',
#   ['set of toy animals sitting in front of red wooden wagon',
#    'several toy animals bull giraffe deer and parakeet',
#    'some toy animals on the ground near picture',
#    'children toy animals are strewn across floor',
#    'display of vintage animal toys on the floor']],
#  '000000561256': ['group of people standing next to each other in room',
#   ['woman wearing hat pink top takes selfie in front of bathroom mirror',
#    'woman in flowered dress taking selfie in bathroom mirror',
#    'an older woman in flower dress takes self photo in the mirror',
#    'woman in yellow bathroom is holding camera',
#    'woman taking picture of herself in bathroom']],
#  '000000338325': ['large jetliner flying through cloudy sky',
#   ['striped plane flying up into the sky as the sun shines behind it',
#    'an airplane is ascending into the white sky',
#    'an american airlines plane is in the sky',
#    'red white and blue plane is in the sky',
#    'plane flies through the sky at an angle']],
#  '000000065485': ['an old pick up truck that is parked on the side of the road',
#   ['dog driving an suv in an open grass covered field',
#    'dog sits in the front seat of jeep',
#    'dog is sitting inside red car',
#    'red truck has black dog in the drivers chair',
#    'dog sitting in the front seat of truck']],
#  '000000226662': ['motorcycle is parked next to parked motorcycle',
#   ['customized motorcycle with more in the background',
#    'black and white photograph of motorcycle',
#    'black and white photo of parked motorcycle',
#    'several custom made motorcycles on display while riders chat',
#    'customized motorcycle with large rear and skinny front tire']],
#  '000000011511': ['man sitting on bench next to stone wall',
#   ['sculpture of two women stting on bench with their purses on the ground while people standing in line behind them',
#    'metal statue of two women sits on bench in city street',
#    'statue of two women with purses sitting on bench',
#    'statue of two people sitting on bench',
#    'metal statue of two women sitting on bench']],
#  '000000221754': ['city street filled with lots of tall buildings',
#   ['there is very little traffic at this city intersection',
#    'an urban intersection with stoplights on cloudy day',
#    'city street with multiple bildings and street light',
#    'four cross street of downtown area',
#    'wide empty street corner filled with buildings']],
#  '000000249025': ['glass vase filled with pink flowers on top of table',
#   ['an orange reddish rose in vase filled with water on top of table',
#    'yellow rose in clear vase filled with water',
#    'there are two yellow flowers inside vase',
#    'beautiful yellow rose is seen in small vase',
#    'two orange roses in small vase with water']],
#  '000000255965': ['black and white cat sitting on top of wooden bench',
#   ['cat pausing as it picture is taken',
#    'blue eyed tabby cat crouched on the ground',
#    'black cat with white stomach takes pose',
#    'cat sitting on street corner looking at the camera',
#    'stripped cat sitting near brick wall']],
#  '000000051598': ['bathroom with toilet sink and toilet',
#   ['black trash bag in restroom next to sink',
#    'garbage bag in white lighted bathroom',
#    'the bathroom has wall sink medicine cabinet toothbrush holder and bare walls',
#    'door is open to white bathroom that has black garbage back on the floor',
#    'the bathroom door is open with the light on']],
#  '000000445846': ['an empty kitchen with sink and refrigerator',
#   ['clean kitchen with the windows white and open',
#    'spacious white kitchen with brown cabinetry sink and appliances',
#    'an office kitchen with open windows and no food',
#    'an extremely plain and outdated white colored kitchen',
#    'kitchen scene is shown with cabinets and appliances']],
#  '000000192871': ['close up of bowl of oranges on table',
#   ['glass bowl filled with oranges on table',
#    'close up of oranges and apples in bowl',
#    'glass bowl has oranges and apples in it',
#    'glass bowl full of oranges and apples',
#    'one apple and several oranges sit in bowl']],
#  '000000365642': ['black and white photo of man riding skateboard',
#   ['young attractive woman sitting on toilette on the side of street',
#    'person sitting on stool on the street',
#    'woman sitting on bucket on the side of street',
#    'woman is sitting on stool on sidewalk',
#    'woman in coat sitting outside on toilet']],
#  '000000393569': ['an image of woman standing in front of large window',
#   ['young woman using laptop computer while sitting on bunk bed',
#    'person that is sitting in bed facing out',
#    'young girl sits in the bottom bunk of her bunkbed',
#    'bedroom with bunk beds and the bathroom next door',
#    'three people live in one room who share bathroom']],
#  '000000116479': ['bed room with two beds and window',
#   ['an old victorian style bed frame in bedroom',
#    'bed in bedroom with white covering next to doorway',
#    'canopy bed with white see through curtains',
#    'white bed and ceiling fan light',
#    'poster bed with canopy in room']],
#  '000000063740': ['laptop computer sitting on top of wooden desk',
#   ['two computers sitting on top of desk',
#    'laptop computer and desktop computer on white desk',
#    'desktop with two computers and fruit on it',
#    'lap top computer next to computer monitor sitting on top of desk',
#    'laptop computer keyboard and two monitors']],
#  '000000570736': ['white toilet sitting next to white sink',
#   ['view of bathroom that is clean',
#    'bathroom with vanity toilet and shower',
#    'the bathroom features vanity sink and tub shower combination',
#    'small bathroom is featured in this photo',
#    'cream themed bathroom with toilet sink with mirror and shower']],
#  '000000492937': ['an image of motorcycle that is parked on the side of the road',
#   ['close up of bike brake on bicycle',
#    'bicycle is chained up to pole at train station',
#    'vintage photo of bike eith lock on it',
#    'close up of bicycle parked on train platform',
#    'the bicycle is locked to the metal pole as the young man waits to board the mass transit train']],
#  '000000117425': ['little girl sitting at table with plate of food',
#   ['toddler celebrates his birthday with cupcake',
#    'young boy with spoon looking at birthday cupcake',
#    'baby holding spoon looking at cupcake and candle',
#    'child holds spoon and looks at cupcake',
#    'young child looking at birthday cupcake']],
#  '000000159977': ['couple of giraffe standing next to each other next to tree',
#   ['giraffe and zebra checking each other out',
#    'giraffe and zebra are on grassy field by the water',
#    'giraffe and zebra walking through an african plain',
#    'giraffe looks down at zebra on the field',
#    'zebra and giraffe in the wild']],
#  '000000232538': ['red and white train traveling down train tracks next to forest',
#   ['yellow and blue train is next to an overhang',
#    'train sits on the track at deserted station overlooked by tower',
#    'colorful train stopped at train station',
#    'passenger train stopped near train station',
#    'train is pulling into the train station']],
#  '000000177934': ['group of people standing next to each other on motorcycle',
#   ['group of women operating car wash',
#    'young women washing motor cycles in the middle of street',
#    'two young women are washing two motorcycles with hoses',
#    'girls wash motorcycle while men look on',
#    'group of people standing near the motorcycles on the street']],
#  '000000096549': ['large passenger jet sitting on top of an airport',
#   ['an airplane on the runway either just landed or ready to take off',
#    'an egyptian airlines plane landing at an airport',
#    'commercial plane on the strip to take off',
#    'jumbo jet touching down on the runway',
#    'egyptair airplane standing on the tarmac at airport']],
#  '000000469192': ['person is flying kite in the sky',
#   ['car is parked on dry grass with kites overhead',
#    'truck driving through field with people flying kites',
#    'an open field with truck and some kites being flown',
#    'pickup truck is parked underneath multiple flying kites',
#    'truck sitting on field with kites in the air']],
#  '000000044652': ['fighter jet flying through cloudy sky',
#   ['flying plane with smoke trailing behind it',
#    'an single passanger in an airplane flying through the sky',
#    'an old airplane is flying through the sky',
#    'an airplane is flying high in the cloudy sky',
#    'small airplane is flying across the sky']],
#  '000000210502': ['passenger train that is pulling into station',
#   ['part of train car with door to the rear connected to the car behind it',
#    'train with striped door waiting on train track',
#    'this the outside of train with slanted striped door',
#    'train on the tracks has black and white striped door',
#    'the side of passenger rail train with stripped door']],
#  '000000298396': ['kitchen filled with lots of dishes and pans',
#   ['kitchen area with counter top space and dining room table',
#    'fully stocked kitchen with no one in it',
#    'an old style kitchen with baby blue cabinets',
#    'very clean and cozy looking kitchen that could be in home magazine',
#    'kitchen filled with appliances dishes and bowl of fruit']],
#  '000000187513': ['bathroom with toilet sink and toilet',
#   ['bathroom with sliding shower door next to toilet',
#    'bathroom with green walls and toilet and shower',
#    'photograph of newly remodeled bathroom in home',
#    'bathroom has green walls and glass shower door',
#    'bathroom with sink mirror toilet and shower']],
#  '000000552883': ['an empty kitchen with stove sink and refrigerator',
#   ['view of kitchen with cabinets sink and clothes washer',
#    'counter top in laundry room with tile back splash',
#    'empty laundry room with lot of storage space',
#    'kitchen with wooden cabinets sink and dish washer',
#    'light green kitchen some cabinets dish washer and sink']],
#  '000000228214': ['the man is holding his cell phone in his hand',
#   ['marine that is looking at his cell phone',
#    'marine in uniform using smart phone',
#    'full dressed marine is looking at his cell phone',
#    'man in uniform is looking at his phone',
#    'service man is looking at his cel phone']],
#  '000000453634': ['white toilet sitting next to white sink',
#   ['bathroom with toilette with it seat down',
#    'bathroom with sink and toilet',
#    'fancy bathroom with clean toilet and piping',
#    'bathroom with toilet sink and shower',
#    'bathroom scene with focus on the toilet']],
#  '000000201775': ['white toilet sitting next to white sink',
#   ['bathroom with two urinals and sink',
#    'white stalls installed on the walls of men room',
#    'men restroom with toilet and urinals along tiled walls',
#    'public bathroom with two urinals on wall and sink with mirror over it on another wall',
#    'two urinals and sink in bathroom']],
#  '000000391375': ['man sitting on wooden bench in front of building',
#   ['girl sitting on bench in front of stone wall',
#    'woman in black sits on park bench',
#    'woman sitting on bench in stone alcove',
#    'young woman in black spotted tights is sitting on bench',
#    'beautiful woman sitting on bench next to stone building']],
#  '000000557501': ['bathroom with sink toilet and toilet',
#   ['bathroom is very colorful with blue yellow and red',
#    'colorful public restroom with striped walls and yellow counter',
#    'bathroom with two sinks near towel and soap dispensers',
#    'restroom with two sinks and red colored stall',
#    'colorful public restroom focused on the sinks']],
#  '000000435880': ['woman standing in front of kitchen counter',
#   ['refrigerator next to red wall in the kitchen',
#    'deep freezer and refrigerator are displayed together',
#    'kitchen has refrigerator and ice chest',
#    'refrigerator and freezer placed next to one another',
#    'fridge with lot of magnets in kitchen']],
#  '000000555050': ['group of people walking down city street',
#   ['car driving in an intersection past furniture shop',
#    'car in front of furniture shop with cow',
#    'small compact car driving past furniture store',
#    'street scene with car passing by',
#    'shop car traffic lights and buildings']],
#  '000000466085': ['white toilet sitting next to white sink',
#   ['bathroom that has been gutted with the shower basin the only thing left',
#    'bathroom that is under construction with standing shower',
#    'an unfinished bathroom with sink and pipes on the floor',
#    'shower base is installed as bathroom undergoes renovations',
#    'rundown bathroom is being stripped and remodeled']],
#  '000000442009': ['bathroom with toilet sink and toilet',
#   ['bathroom with bath tub near windows',
#    'bathroom scene is shown with tub and counter',
#    'bathroom with bathtub and sink overlooking blue ocean',
#    'bathroom with big white tub with legs',
#    'bathroom scene complete with cast iron style tub']],
#  '000000127987': ['computer mouse sitting on top of wooden desk',
#   ['baseball player bobble head next to two computer monitors on desk',
#    'close of bobble head doll with computer in the background',
#    'bobble head is shown next to computer screens',
#    'bobble head baseball figurine on desk',
#    'desk with two computer screens and cecil cooper bobble head']],
#  '000000368335': ['brown and white cow standing in the middle of field',
#   ['brown horse is walking in between two cars',
#    'horse walks between cars in parking lot',
#    'horse walking between the parking spaces of two cars',
#    'horse is standing between two parked cars',
#    'from the rear we see horse standing between two cars parked in parking lot']],
#  '000000423798': ['traffic light sitting on the side of road',
#   ['street at night is lit up by streetlights',
#    'motion blur street scene with the car lights streaking',
#    'an empty street at night with bright lights shining from the light poles and one very bight light reflecting off the pavement',
#    'beams of light coming off of different objects on city street',
#    'the head beams from the vehicle can be seen clearly as the vehicle makes it way up the street under the street lights']],
#  '000000140420': ['person riding bike on the side of road',
#   ['motorcycle is parked on dirt road in forest',
#    'loan bike sits by itself on dirt road on bend in wooded area',
#    'motorcycle is parked on tree lined dirt road',
#    'motorcycle on dirt road by stream and trees',
#    'motorcycle is parked on gravel road in forest by stream']],
#  '000000204186': ['group of people riding on the back of red motorcycle',
#   ['racers riding four wheelers while crowd watches',
#    'spectators enjoying show of two men on four wheelers',
#    'two men ride on atv and tilt them to the side',
#    'two men doing stunt show on four wheeler atv vehicles',
#    'young man performing trick on an atv on field']],
#  '000000040471': ['large kitchen with stove and refrigerator',
#   ['an older picture of large kitchen with white appliances',
#    'an all white painted kitchen with ceiling fan',
#    'painted white kitchen with refrigerator and an automatic dish washer next to an oven stove',
#    'small white kitchen with ceiling fan hanging down',
#    'white kitchen with ceiling fan stove and refrigerator']],
#  '000000010363': ['cat that is sitting on top of car',
#   ['gray cat standing on top of black car',
#    'cat standing on the hood of car',
#    'grey color cat standing on hood of car in garage',
#    'gray cat on the hood of black car',
#    'cat sitting on the hood of parked black car in garage']],
#  '000000173008': ['man standing in kitchen preparing food',
#   ['man in tropical print shirt with glasses and long hair is eating banana',
#    'man wearing hawaiian shirt eats banana instead of pastries',
#    'man taking bite of half peeled banana',
#    'person eating banana in kitchen',
#    'man eating banana at kitchen counter']],
#  '000000452793': ['an empty kitchen with sink and refrigerator',
#   ['kitchen with granite counter top and faucet',
#    'kitchen with stainless steel fridge and granite counters',
#    'kitchen with big fridge and big sink',
#    'this new fridge goes great in this clean kitchen',
#    'view of kitchen sink stainless refrigerator and breakfast room']],
#  '000000456865': ['large passenger jet sitting on top of an airport tarmac',
#   ['an airplane just landed on the runway',
#    'large plane sits on the large runway',
#    'large white airplane parked upon runway',
#    'an airplane sitting on the tarmac with clouds above it',
#    'airplane on the runway and cloudy sky']],
#  '000000504711': ['piece of cake on plate next to fork',
#   ['fork rests on plate next to piece of cake',
#    'piece of chocolate cake sits on plate with fork',
#    'piece of chocolate cake and fork on plate',
#    'closeup on some chocolate cake has fork by it',
#    'piece of dutch chocolate cake with fork on plate']],
#  '000000288584': ['group of giraffes standing next to each other on field',
#   ['person dressed as giraffe carrying bullhorn',
#    'group of people collect around giraffe head',
#    'person in giraffe costume in crowd of people',
#    'somebody wearing giraffe costume greets people at park',
#    'person with giraffe costume greets people coming through the gate']],
#  '000000551304': ['white toilet sitting next to white toilet',
#   ['white and gold fancy toilet and stainless trash can',
#    'fancy toilet bowl with golden scroll work on it',
#    'well decorated toilet seat with undecorated surroundings',
#    'bathroom with decorated toilet near trash can',
#    'photograph of very decorated toilet in bathroom']],
#  '000000276284': ['motorcycle is parked on the side of the road',
#   ['motorcycle is parked in parking lot',
#    'lone motorcycle parked in parking space at night',
#    'motorcycle in parking lot with sky background',
#    'motorcycle in parking lot at night',
#    'lone motorcycle is parked in the lighted parking lot']],
#  '000000103548': ['herd of cattle standing on top of lush green field',
#   ['herd of animals traveling down country road surrounded by lush green landscape',
#    'jogger running past flock of sheep in rural area',
#    'man walking beside sheep on country road',
#    'jogger running past flock of white sheep',
#    'runner wearing spandex has come across large herd traveling down the dirt road']],
#  '000000226408': ['woman laying down on bed with teddy bear',
#   ['child laying down with arms extended in the air',
#    'black and white photograph of girl on bed',
#    'an image of girl playing with doll',
#    'blurry black an white image of girl laying down',
#    'girl lying down and smiling and feeling happy']],
#  '000000558073': ['the cat is sitting in the sink in the bathroom',
#   ['cat sitting in bathtub not looking amused',
#    'an adult cat is sitting inside of bathtub',
#    'tiger cat sitting in white bathtub',
#    'striped cat sits in bath tub',
#    'cat messing around in the white bathtub']],
#  '000000102411': ['group of people riding on the back of motorcycle',
#   ['two people riding motorcycle to the beach',
#    'man riding motorcycle with woman on the back',
#    'two people sitting on motorcycle in the street next to beach',
#    'two people are riding motorcycle on the beach',
#    'couple sit on motorcycle at the beach']],
#  '000000048924': ['man standing next to an open umbrella next to tree',
#   ['dirt bike parked near tent in the woods',
#    'green tent and parked motorcycle and some trees',
#    'motorcycle parked in front of tent with the sun going down behind them',
#    'motorcycle parked next to green tent in field',
#    'parked motorcycle next to green tent']],
#  '000000230008': ['group of people riding on the back of motorcycle',
#   ['traffic motorcycle cop waits to give ticket',
#    'police officer on motorcycle sitting at the corner',
#    'police officer is outside on his bike',
#    'police officer laying speed trap for the purpose of writing ticket',
#    'police man on motorcycle is idle in front of bush']],
#  '000000181666': ['group of people standing next to herd of cattle',
#   ['flock of goats and some men watching them',
#    'man and large herd of goats in desert setting',
#    'the nomadic sheepherd walks behind large group of livestock in their desert habitat',
#    'man is herding his goats is the desert',
#    'men keep watch on herd of goats']],
#  '000000543047': ['living room filled with furniture and flat screen tv',
#   ['scene of an apartment with dining table and couple of couches',
#    'living room and dining room have two tables couches and multiple chairs',
#    'colorful living area with living room dining room and kitchen',
#    'living area with purple couches looking into the dining area',
#    'living room and dining room are in pink and green']],
#  '000000565391': ['an old pick up truck that is parked on the side of the road',
#   ['jeep with dead bird on the windshield',
#    'cat sleeps on top of parked jeep',
#    'parked jeep with cat laying on it hood',
#    'black and white cat laying on top of jeep',
#    'cat sleeping on the hood of convertible jeep']],
#  '000000485802': ['fighter jet flying through blue sky',
#   ['an airplane leaving trail in the sky',
#    'plane flying straight up and high in the sky leaves tail of smoke',
#    'an airplane leaves contrail in the air',
#    'plane accelerating through the sky leaving tail',
#    'plane flying in the sky with trail of white smoke behind it']],
#  '000000086220': ['group of people standing next to each other in front of double decker bus',
#   ['car and public transit vehicle on road',
#    'car in front of train on train tracks',
#    'tram and car make their way through town',
#    'silver car in the street next to metal railing',
#    'white car and white bus parked parallel from one another']],
#  '000000412894': ['traffic light sitting on the side of city street',
#   ['dozens of people walking around metro area',
#    'people walk down busy city street with traffic light',
#    'bunch of people crossing the street in city',
#    'people cross the street at the corner of luxury buildings',
#    'people are walking across the street at an intersection']],
#  '000000099054': ['large passenger jet sitting on top of an airport tarmac',
#   ['some planes on an air port run way',
#    'large jet airplane sitting on tarmac at an airport',
#    'an airplane parked at the runway is being serviced by workers',
#    'an airplane being prepped for flight as another plane passes by',
#    'an airplane is at an airport with yellow hoses by it']],
#  '000000026564': ['desktop computer sitting on top of wooden desk',
#   ['an office desk with row of books and desktop computer and laptop computer on the desk',
#    'desktop computer next to laptop computer',
#    'desk with laptop some keyboards and some books',
#    'there is desktop computer and laptop sitting on an organize desk in an office',
#    'office desk with monitor laptop and books']],
#  '000000062025': ['small bathroom with toilet sink and shower',
#   ['an image of hotel bathroom that is ugly',
#    'small bathroom where the vanity is over the sink and toilet',
#    'bathroom contains toilet and sink below vanity',
#    'bathroom has an mirror with an overhead light',
#    'bathroom with sink toilet and tub in front of large mirror']],
#  '000000489091': ['bathroom with toilet sink and shower',
#   ['residential bathroom has modern motel look with upgraded fixtures and accessories',
#    'small bathroom with large mirror and single sink vanity',
#    'white bathroom that has been newly cleaned',
#    'bathroom sink next to white toilet under large mirror',
#    'vanity and toilet are in bathroom under mirror']],
#  '000000155154': ['white toilet sitting next to bathroom sink',
#   ['the bathroom is small and white and gray',
#    'small white chamber contains various devices and doors',
#    'bathroom with significant modifications made to it',
#    'small bathroom on an airplane with handles on either side',
#    'some sort of bathroom facility possibly in an airplane']],
#  '000000071711': ['an airplane that is in the air at an airport',
#   ['large airplane museum with old war planes',
#    'group of old planes on display in museum',
#    'an indoor museum exhibit features several old planes',
#    'an air hanger with two world war two airplanes parked next to each other',
#    'group of people walk around old planes in hanger']],
#  '000000152771': ['person riding skate board at skate park',
#   ['bike in the middle of an empty parking lot next to trees',
#    'an empty parking lot features green trees and single white bicycle',
#    'bicycle parked in an empty parking lot by itself',
#    'lone bicycle parked in parking lot with cars parked on street',
#    'bicycle stands in the middle of an empty parking lot']],
#  '000000437392': ['white toilet sitting next to bath tub',
#   ['toilet that is decorated like pink stuffed animal',
#    'pink monster made out of toilet seat with googley eyes',
#    'pink think with mop for hair and bulging eyeballs',
#    'pink handmade puppet sits on the floor',
#    'pink puppet toy with googly eyes on hanger']],
#  '000000571804': ['table topped with lots of dishes on top of it',
#   ['ten porcelain pieces with floral patterns painted on them',
#    'collection of sinks and basins are on display',
#    'fine china stays on display not to be touched',
#    'porcelain tea and bathroom set is on display',
#    'collection of soap dishes bowls and small trinkets']],
#  '000000078404': ['woman sitting on bench reading book',
#   ['three women sitting on park bench next to each other',
#    'group of women sitting on full bench',
#    'ladies sitting together on bench in the park',
#    'group of women sitting on park bench',
#    'the bench maximum weight capacity may be strained']],
#  '000000308631': ['group of motorcycles parked next to each other next to building',
#   ['people stand around an antique motorcycle in grassy area',
#    'an old with motorcycle with people standing beside it',
#    'motorcycle parked in front of crowd of people',
#    'people standing around home built motorcycle used for racing',
#    'group of people gathered around an old dirty vintage motorcycle']],
#  '000000423971': ['white toilet sitting next to white toilet',
#   ['toilet with an illuminated seat in restroom',
#    'bathroom with fancy toilet in it',
#    'modern looking commode in very tiny bathroom',
#    'toilet with open lid in the middle of bathroom',
#    'bathroom scene with modern toilet and wooden fixtures']],
#  '000000304560': ['black and white photo of black and white cat',
#   ['black ct with green eyes sitting in the sun',
#    'cat that is staring at the camera',
#    'black cat sitting in field of grass',
#    'black cat with yellow eyes sitting in the grass',
#    'black cat is staring directly into the camera']],
#  '000000221708': ['living room filled with furniture and flat screen tv',
#   ['lights shine on wooden dining room table',
#    'kitchen with table and four chairs',
#    'partial picture of kitchen and table and chairs under lamp',
#    'small table and chairs set in small kitchen',
#    'wood paneled kitchen with dining table and tiled floor']],
#  '000000026204': ['group of people walking down street next to tall buildings',
#   ['street filled with lots of traffic next to tall buildings',
#    'cars and bus are stopped at an intersection',
#    'many vehicles stopped on city street',
#    'number of vehicles waiting at an intersection',
#    'group of cars waiting at an intersection for the light to change']],
#  '000000085576': ['white toilet sitting next to sink in bathroom',
#   ['commercial bathroom stall with empty toilet paper holders',
#    'an empty toilet stall with two rolls of used toilet paper and one full roll',
#    'toilet in restroom next to busted toilet paper dispenser',
#    'the toilet paper containers in this public restroom are empty and need to be refilled',
#    'two empty toilet paper roll holders hang in the stall while the empties lay around and nice roll sets on the bar']],
#  '000000153217': ['black and white photo of black and white photo of black and white photo of an old black and white photo of black and white photo of black and white photo of an old black and white photo of an old black and white photo of motorcycle',
#   ['black cat standing in front of motorcycle',
#    'black cat with arched back walking past motorcycle',
#    'black cat posing in front of motorcyle',
#    'cat walks next to motorcycle on sidewalk',
#    'black cat meanders up the walkway in front of motorcycle in front of house']],
#  '000000270066': ['motorcycle is parked on the side of the road',
#   ['motorcycle is parked near puddle and van',
#    'white and black motorcycle sits next to van in parking lot',
#    'white and black motorcycle sits in parking spot',
#    'white motorcycle sitting in front of van',
#    'white motorcycle parked next to sidewalk']],
#  '000000348708': ['bowl of cereal sitting on top of counter',
#   ['the banana is laying next to an almost empty bowl',
#    'bowl of food next to very close banana',
#    'banana and nearly empty bowl of food resting on top of table',
#    'bowl with something in it with banana next to it',
#    'bowl filled with leftover food sitting next to banana']],
#  '000000224051': ['man riding bike down the side of the road',
#   ['bike is perched on concrete girder on the road',
#    'bike parked on the side walk and car on the street',
#    'bicycle parked by the side of busy highway on concrete slab',
#    'bicycle parked near curb on the highway',
#    'bicycle sits parked along busy roadside']],
#  '000000163746': ['group of people standing on top of sandy beach',
#   ['pretty young girl standing next to another pretty young girl on beach',
#    'people walking onto the beach from the water',
#    'two almost identical photos with some minor cropping show two young girls standing on the coast with people in the water in the background as plane flies overhead',
#    'girls playing on beach with an airplane flying above them',
#    'people on the beach really close to the water']],
#  '000000382122': ['tall building with clock on the top of it',
#   ['large church building with massive clock tower',
#    'church building with tall narrow clock tower',
#    'church with clock stands behind fence',
#    'large brick building with clock tower at its height',
#    'tall tower with clock on top']],
#  '000000571857': ['group of people standing on top of sandy beach',
#   ['in the desert two people are sitting next to small propeller plane next to tent with other planes in the background',
#    'couple of people sitting in chairs behind an airplane',
#    'man and woman who have set up camp on sandy beach',
#    'two people outside sitting on chairs with planes around them',
#    'two people are camping out in the desert']],
#  '000000209747': ['the cat is drinking water from the bowl',
#   ['gray and white kitten sitting in bathroom sink',
#    'the tiny kitten looks sad sitting in the bathroom sink with scrub brush on the rim',
#    'gray and white kitten in white bathroom sink',
#    'kitten sitting in skin with green brush with green bristles',
#    'kitten looking puzzled sitting in bathroom sink']],
#  '000000575205': ['red and white plane sitting on top of grass covered field',
#   ['small plane is preparing to land on the strip',
#    'small airplane coming in for landing',
#    'small airplane is in the air on runway',
#    'plane on runway taking off above ground',
#    'small plane taking off from run way in mid air']],
#  '000000017379': ['flat screen tv sitting on top of hard wood floor',
#   ['flat screen tv embedded in restroom mirror',
#    'tv in bathroom mirror next to sinks',
#    'football game on tv reflects in bathroom mirror',
#    'flat screen tv adorns bathroom mirror',
#    'photo of video game in the middle of large mirror in bathroom']],
#  '000000055002': ['white toilet sitting next to bathroom sink',
#   ['metallic toilet sitting in small bathroom',
#    'an overhead of stainless steel open toilet with man feet stradling',
#    'man standing over shiny metal toilet',
#    'an aerial view of an open toilet seat that someone is standing in front of',
#    'metal commode from above photographer shoes visible']],
#  '000000202228': ['the man is taking picture of himself in mirror',
#   ['the reflection of man taking picture in mirror',
#    'man takes his picture using the bathroom mirror',
#    'man wearing hat while standing in front of bathroom mirror',
#    'man taking picture of himself in mirror',
#    'young man takes picture of himself in the mirror']],
#  '000000194832': ['train that is pulling into train station',
#   ['television screen is displayed in an empty bus',
#    'vacant bus has seats facing in multiple directions',
#    'the inside of commuter city bus with palide seats',
#    'an empty bus with brown cloth covered seats',
#    'an empty bus has tartan seats and wooden floor']],
#  '000000147518': ['white toilet sitting next to white sink',
#   ['bathroom that has magazine rack and small cabinet',
#    'compact bathroom area tub toilet magazine area and sink',
#    'small residential bath room decorated in wood tones',
#    'tissue box on top of toilet in bathroom',
#    'an image of clean full bathroom']],
#  '000000003661': ['close up of bunch of bananas on table',
#   ['bunch of bananas sitting on top of wooden table',
#    'closeup of group of bananas on table',
#    'the four huge bananas are still connected together',
#    'close up of bunch of bananas on wooden counter',
#    'bunch of bananas very close up on table']],
#  '000000147740': ['woman standing next to man in front of fire hydrant',
#   ['woman walking while carrying bananas on her hat',
#    'woman carrying bunch of bananas on her head walking down street',
#    'woman carrying bunch of bananas on top of her hat',
#    'woman walks down the street with bananas on her hat',
#    'lady walks down the street with bananas on her head']],
#  '000000243204': ['young boy standing in front of toilet',
#   ['person is holding spatula near slices of bread on stove',
#    'person bundled in winter clothing and scarf cooking',
#    'man is cooking while wearing jacket and scarf',
#    'person that is cooking some food in kitchen',
#    'person bundled up while frying something on the stove indoors']],
#  '000000368900': ['living room filled with furniture and flat screen tv',
#   ['cluttered room filled with tv and kitchen',
#    'room with television set stool and some pictures',
#    'small apartment has many belongings in it',
#    'the front room of an apartment with the basics',
#    'tv sits in room with many other things']],
#  '000000214192': ['person on motorcycle riding down the road',
#   ['two motocross racers in the middle of race',
#    'two competitors skidding during dirt bike competition',
#    'picture of two motorcross people skidding in the dirtroad',
#    'two people on dirt bikes making turns on track',
#    'couple of dirt bikers in race']],
#  '000000134096': ['black and white photo of cat in bathroom sink',
#   ['calico cat drinking from sink faucet',
#    'cat attempting to get drink out of faucet',
#    'cat drinking out of the faucet of sink',
#    'calico cat drinks water from faucet',
#    'cat drinking water from bathroom faucet']],
#  '000000441586': ['group of people riding on the back of motorcycle',
#   ['man on contraption surrounded by bicycle and another person',
#    'man on piece of equipment resembling bicycle that has very large wheels',
#    'man on beech vehicle making his way thru the sand',
#    'person riding two thick wheeled bike on sand',
#    'man standing on vehicle with two large wheels']],
#  '000000425221': ['view of clock tower in the middle of town',
#   ['plane is flying away from the airport',
#    'person at an airport terminal with planed in view outside of the windows',
#    'large terminal in quiet airport hall',
#    'man waits in an airport terminal as planes take off',
#    'people in an air port waiting area']],
#  '000000163155': ['black and white cat sitting on top of chair',
#   ['cat crouched over sitting by brick wall',
#    'gray and white tiger striped cat sitting in front of brickwall',
#    'cat perched near brick wall looking to he right',
#    'cat crouched on the edge of porch',
#    'cat sitting in pouncing position next to brick wall']],
#  '000000216497': ['living room filled with furniture and flat screen tv',
#   ['some chairs sit at an island near an open door',
#    'kitchen in house under construction and painting',
#    'kitchen featuring an open island for seating with high back stools',
#    'in an unfinished room counter sits with three chairs while stove and cabinets sit in the distance',
#    'kitchen with stove table some chairs and sink']],
#  '000000515266': ['an old truck is parked on the side of the road next to truck',
#   ['white truck parked next to white trailer',
#    'large truck is parked beside an old wooden bench',
#    'truck and trailer sit behind long bench',
#    'an image of truck with side trailer',
#    'wooden bench with an old tire sitting on it']],
#  '000000360564': ['white toilet sitting next to white sink',
#   ['walk in shower next to toilet with wooden seat',
#    'the neat bathroom has green trim on the tile',
#    'toilet with wood seat and tiled floor',
#    'this bathroom has pattern of blue tiles on the floor',
#    'bathroom with blue tile outline around the floor']],
#  '000000090631': ['large jetliner flying through blue sky',
#   ['colorful fighter jet flying through blue sky',
#    'jet with lots of colors leaving trail in the sky',
#    'there is jet plane that is painted multi color',
#    'colorful plane leaves trail of smoke on clear blue sky',
#    'mulitcolored plane is flying in the sky']],
#  '000000427338': ['clock tower in the middle of an empty street',
#   ['city made out of stone brick with large arches',
#    'two men are riding motorcycles through some ruins',
#    'person on motorcycle in very scenic rock area',
#    'person riding motorcycle in an abandoned stone building',
#    'man taking picture of narrow walkway']],
#  '000000058705': ['group of people standing next to each other',
#   ['man wearing helmet while holding banana next to woman wearing helmet',
#    'two people posing in funny hats for camera',
#    'man and woman at party dressed in costumes',
#    'man and woman posing together for picture',
#    'there are two people posing and one man is holding banana']],
#  '000000360943': ['cat is looking out the window of window',
#   ['an orange cat sitting in front of door to house',
#    'small black cat sits outside on an open window sill',
#    'an orange cat sits on stoop in front of door',
#    'an orange tabby cat lies down outside door on house porch',
#    'fat orange cat sitting on deck']],
#  '000000302760': ['sink and mirror in bathroom next to sink',
#   ['bathroom sink with marble counter top under large mirror',
#    'an image of bathroom with sink and mirror',
#    'soap and water bottle are on top of vanity in teal bathroom',
#    'view of sink with soap next to it',
#    'bathroom sink with bottle of hand soap']],
#  '000000252219': ['group of people standing next to each other in front of building',
#   ['person with shopping cart on city street',
#    'city dwellers walk by as homeless man begs for cash',
#    'people walking past homeless man begging on city street',
#    'homeless man holding cup and standing next to shopping cart on street',
#    'people are walking on the street by homeless person']],
#  '000000313182': ['blue and white double decker bus driving down street',
#   ['purple and white bus driving down street',
#    'purple and white city bus pulling up to the curb',
#    'purple and white bus in parking lot',
#    'purple bus with person on the side driving around curb',
#    'bus sits diagonal from the curb next to building and people']],
#  '000000098520': ['large passenger jet sitting on top of an airport tarmac',
#   ['large passenger jet sitting on top of an airport runway',
#    'large commercial airplane sitting on runway',
#    'an airplane makes its way down snowy runway',
#    'plane siting on showy tarmac at an airport',
#    'jet is towed down the tarmac on dreary gray day']],
#  '000000354072': ['bathroom with toilet sink and toilet',
#   ['bathroom sink under mirror next to plant',
#    'bathroom with round sink and red tile backsplash',
#    'large plant is in the corner of small bathroom',
#    'bathroom has circular sink with red tiles',
#    'white bathroom with large circular sink']],
#  '000000206135': ['herd of cattle standing on top of grass covered field',
#   ['herd of cattle sitting in front of church with steeple',
#    'the view of four cows standing in row from behind',
#    'four cows stand in the parking lot of church',
#    'four cow rears stand in front of building with steeple',
#    'there are four cows standing on the side of road']],
#  '000000308799': ['an empty kitchen with stainless steel appliances and stainless steel appliances',
#   ['doorway into clean wood floored kitchen',
#    'black and silver kitchen with wood floors',
#    'contemporary kitchen featuring wood floors and stainless steel oven',
#    'picture of very nice kitchen with the light on',
#    'kitchen with hardwood floors and sink and oven']],
#  '000000205514': ['living room filled with furniture and flat screen tv',
#   ['the large living room has been decorated in modern furnishings',
#    'flat screen mounted to wall in living room',
#    'an all white living room with stone flooring',
#    'room where all the furniture and the walls are white',
#    'room with all white furniture in front of flat screen']],
#  '000000537812': ['white toilet sitting next to white sink',
#   ['tiled bathroom with toilet and open shower',
#    'an orange bucket sitting on stool in bathroom',
#    'red bucket is on stool in the bathroom',
#    'bathroom with toilet and small bucket on small stool',
#    'small bathroom with two containers catching plumbing drips']],
#  '000000284623': ['black cat sitting on top of wooden table',
#   ['black cat sits in bathroom sink',
#    'black cat looking intently at the camera',
#    'black cat sitting on top of bathroom sink',
#    'black cat sitting inside bathroom sink',
#    'black cat with green eyes sitting in bathroom sink']],
#  '000000136355': ['living room filled with lots of furniture and furniture',
#   ['kitchen with bright window and house plants',
#    'kitchen with wooden furniture and vase filled with red flowers',
#    'kitchen table and chairs with greenery and tulips',
#    'bright kitchen with tulips on the table and plants by the window',
#    'vase of flowers on dining table']],
#  '000000001761': ['large jetliner flying over body of water',
#   ['two planes flying in the sky over bridge',
#    'sky photo to jumbo jet airplanes over bridge',
#    'two planes fly over bridge in sydney australia with the sydney opera house in the background',
#    'two jets are flying over bridge and some water',
#    'two airplanes flying in the sky above black bridge']],
#  '000000267351': ['tall clock tower on top of building',
#   ['large clock tower is yellow and white',
#    'the white and yellow clock with red roof reads',
#    'tower white with yellow trim tower features large clock',
#    'yellow and white clock tower against blue sky',
#    'two clocks on perpendicular facades of church bell tower']],
#  '000000357567': ['white toilet sitting next to bath tub',
#   ['small bathroom with white toilet next to shower curtain covered bath tub',
# ...
#   ['bus traveling down curvy road behind black car',
#    'group of people cross the curved street',
#    'curve in city road with bus following car and people walking on the side',
#    'group of people walk alongside the road',
#    'fish eye view of bus rounding curve on city street']],
#  '000000439715': ['group of people riding on the backs of brown horses',
#   ['man riding brown horse in uniform next to tall green trees',
#    'man in uniform riding horse by fence',
#    'an image of man on top of horse',
#    'man in uniform rides horse down the street',
#    'person in red peacoat and hat riding horse']],
#  '000000055072': ['couple of giraffe standing next to each other next to tree',
#   ['single giraffe looks over the green brush',
#    'an adult giraffe grazing in brown field',
#    'giraffe leans its neck as it walks through the bush',
#    'there is giraffe bending over to chew some brush',
#    'giraffe standing in straw field next to shrubbery']],
#  '000000167902': ['close up of person holding an umbrella',
#   ['black and yellow bird with colorful beak',
#    'black and yellow bird with colorful beak sitting on branch',
#    'large yellow and black toucan sitting on top of tree branch',
#    'colorful toucan perched on branch in some trees',
#    'little black bird with big colorful beak sitting on branch']],
#  '000000338718': ['street sign is on the side of the road',
#   ['street sign reading cambridge st and norfolk st crossing lies broken on the ground',
#    'the norfolk and cambridge road signs have fallen to the ground while van drives by',
#    'picture of street sign that is on the ground',
#    'broken street sign lays on the side of road',
#    'street scene with the street sign knocked over']],
#  '000000478862': ['an airplane sitting on top of an airport tarmac',
#   ['groups of people walk around huge multi engine airplane',
#    'an army plane sitting on the tarmac',
#    'large propeller airplane parked on an airport tarmac',
#    'large plane with two propellers on it',
#    'groups of people admire large propeller plane on the runway']],
#  '000000548780': ['couple of people sitting on park bench',
#   ['two sexy young women sitting on metal bench in front of flowers',
#    'two women sitting on metal park bench',
#    'two people sit on bench with pigeons and other people nearby',
#    'two women sitting on bench in the park',
#    'two women sitting on bench with one smoking cigarette']],
#  '000000579893': ['red stop sign sitting on top of metal pole',
#   ['close up of the stop sign and to street signs',
#    'close up of street sign with sky background',
#    'the stop sign is at four way intersection',
#    'stop sign located at the intersection of east village and woodfield rd',
#    'red stop sign with two green street signs on top of it']],
#  '000000543043': ['car is parked on the side of the side of the road next to car',
#   ['there is red car parked next to an old bus',
#    'red mustang is parked in front of schoolbus boat house',
#    'nice red car parked in front of roadside junk sale',
#    'car sits next to bus with things in front of it',
#    'red car parked in front of an abandoned bus']],
#  '000000476491': ['red fire hydrant in front of brick building',
#   ['an alley between two buildings with sky in the background',
#    'small road is shown behind building',
#    'narrow road in city between two buildings',
#    'fairly dark and narrow street in asia',
#    'day time view of narrow street in city']],
#  '000000527616': ['living room filled with furniture and flat screen tv',
#   ['television screen in an open space at political function',
#    'television set with politician on the screen',
#    'picture of someone in the tv on the wall',
#    'room that houses several pieces of campaign memorabilia',
#    'television is in wall and on']],
#  '000000189698': ['stop sign that is next to tree',
#   ['picture of road sign labeled bodacious drive',
#    'green street sign that says bodacious drive',
#    'clean street sign that reads bodacious dr',
#    'this green street name sign says bodacious drive',
#    'street sign in neighborhood during the day']],
#  '000000198928': ['traffic light sitting on top of street next to tall buildings',
#   ['woman standing next to light pole by street',
#    'woman stands next to traffic light',
#    'the woman is standing by the stop light',
#    'woman stands next to lamp post with street light on it',
#    'woman at crosswalk that has green light']],
#  '000000153632': ['close up of plate of food on table',
#   ['side of meat sitting on white plate on dinner table',
#    'plate of food at the table with meat',
#    'some interesting food sitting on white plate by knife',
#    'here is plate of food that appears to have been browned in butter',
#    'white plate topped with food sitting on table']],
#  '000000236690': ['small bird standing on top of body of water',
#   ['white and gray bird soaring over the blue ocean',
#    'large water bird flying over the ocean',
#    'large white bird flies over the water',
#    'an image of bird flying over the water',
#    'white bird fly in the air above the blue water']],
#  '000000343315': ['red fire hydrant sitting on the side of the road',
#   ['red fire hydrant sitting on patch of green grass',
#    'sidewalk grass median with street sign and fire hydrant',
#    'patchy lawn road sign and fire hydrant',
#    'red fire hydrant on curb by street',
#    'red fire hydrant on street corner near sign']],
#  '000000084170': ['red double decker bus driving down street next to tall buildings',
#   ['red and white bus and some cars in the rain',
#    'bus makes splash in the heavy rain',
#    'bus that is driving through the rain',
#    'bus driving on rain covered street',
#    'bus and few cars are riding in the rain']],
#  '000000490125': ['flock of birds standing on top of grass covered field',
#   ['white birds are gathered around water puddle',
#    'group of birds in bunch of puddles',
#    'white birds getting drink from the water puddles',
#    'several white birds standing in puddle in parking lot',
#    'flock of white birds stands in parking lot puddle']],
#  '000000015746': ['red fire hydrant sitting in the middle of field',
#   ['fire hydrant is standing amid some grass',
#    'red and black fire hydrant is positioned in front of dwelling',
#    'fire hydrant in front of house with overgrown grass',
#    'picture of fire hydrant in the grass',
#    'the fire hydrant in the green grass is red']],
#  '000000222235': ['close up of cat laying on top of grass covered field',
#   ['cat is playing with plan in park',
#    'cat attacks weeds in landscaped area',
#    'cat plays with grass outside in the garden',
#    'cat playing with an outdoor plant with long grass on it',
#    'cat sits on its hind legs and swats at the plant']],
#  '000000029397': ['young boy riding skateboard on top of ramp',
#   ['person wearing orange pants standing on bench',
#    'someone in orange pants stands on wooden bench',
#    'man standing on bench with sign next to them',
#    'person in red pants stands on wooden bench with poster',
#    'an image of boy standing on top of bench']],
#  '000000449198': ['train traveling down train tracks next to tall building',
#   ['time shot of cars driving down asian highway',
#    'motion blur photograph of an oriental street at night',
#    'road travels through an industrial area at night',
#    'set of train tracks underneath bridge over pass',
#    'roadway at night with an overpass walkway above the road']],
#  '000000090208': ['red double decker bus driving down city street',
#   ['the picture of three buses on lot',
#    'three double decked buses are parked on pavement',
#    'several green and red double decker buses lined up parked',
#    'green double decker bus sits at the front of row of buses',
#    'green and two red double decker tour buses']],
#  '000000113051': ['boat that is sitting in the water',
#   ['boat traveling into water filled tunnel',
#    'speed boat is docked underneath dark shadowy bridge',
#    'boat in the water next to rail in tunnel',
#    'motorboat docked on pier under tunnel',
#    'small boat on body of water on harbor']],
#  '000000255718': ['statue of statue of an elephant statue in the middle of the street',
#   ['rusty old fire hydrant on an inner city street',
#    'close up of rusty fire hydrant',
#    'rusted fire hydrant planted firmly on the ground',
#    'the tall object is very old and rusty looking',
#    'close up picture of fire hydrant on street']],
#  '000000514376': ['train traveling down train tracks next to tall buildings',
#   ['trolley is going down the street while car passes it',
#    'an electric trolley bus on the street in seattle',
#    'bus drives through city street with building in the background',
#    'city bus driving down street next to hotel',
#    'electric trolly bus driving in the middle of street with building behind it']],
#  '000000041488': ['there is no image here to provide caption for',
#   ['the road sign says east queens bronx',
#    'highway road sign directing the way ahead',
#    'large and green interstate exit sign above road',
#    'green road sign showing the queens bronx exit',
#    'an green and white overhead street sign on interstate for queens and bronx showing truck restriction']],
#  '000000499181': ['there are many people walking down the street',
#   ['street scene of self service parking lot',
#    'there are many cars that are parked in the parking lot',
#    'black building that says first avenue and street entry',
#    'self service parking lot with building behind it and an intersection in front of it',
#    'parking lot with few cars in it']],
#  '000000185472': ['train traveling down train tracks next to forest',
#   ['the train is approaching and man is getting off his bicycle',
#    'train approaching station with man and bike on it',
#    'train is pulling up to people waiting and crossing guard getting off his bike',
#    'group of passengers at train station standing on the platform as train arrives',
#    'person getting off bike and train coming on the tracks']],
#  '000000344029': ['double decker bus traveling down city street next to tall buildings',
#   ['bus that is driving down the road',
#    'city bus is driving through the town',
#    'no image again there are lot of these lately',
#    'city bus is driving down the road next to buildings',
#    'black passenger bus navigating paved city streets']],
#  '000000315001': ['group of people standing on top of sandy beach',
#   ['flock of birds flying over the ocean next to beach',
#    'flock of seagulls flying over the water together',
#    'picture of some birds are flying around in the air',
#    'seagulls in flight and standing on beach at sunset',
#    'an ocean view with dozens of birds in the sky']],
#  '000000195045': ['park bench in front of house with trees in the background',
#   ['park filled with green grass and tall leaf filled tree',
#    'bench under tree in park',
#    'an empty field with older structure in the background',
#    'picture of little house and some grass',
#    'storage building located near town park']],
#  '000000117374': ['black and white photo of two dogs playing with frisbee',
#   ['two cats sitting in the dirt under tree',
#    'couple of cats are by tree',
#    'an image of two cats in sand lot',
#    'two cats by tree in the dirt',
#    'several cats sitting near tree and bird on fence post']],
#  '000000429718': ['red train traveling down train tracks next to forest',
#   ['train with steam coming out is on the tracks',
#    'an old style green train moving along train tracks',
#    'an old fashioned train rounds the corner on train tracks',
#    'smoke is emanating from train that is on track that is curving',
#    'black and green train locomotive engine traveling along railroad track']],
#  '000000289586': ['giraffe standing next to wooden fence',
#   ['giraffe points its head towards the sky',
#    'giraffe stretching its next long to reach branch',
#    'giraffe raises its head in front of rocks',
#    'giraffe in the display at the zoo',
#    'giraffe trying to reach some leafs on tree']],
#  '000000055167': ['red double decker bus driving down street next to tall buildings',
#   ['yellow and blue bus traveling down road next to park',
#    'yellow and blue bus drives down the road',
#    'yellow and blue public bus driving down the road by some flowers',
#    'large bus driving down road',
#    'public transit bus in city street']],
#  '000000360325': ['black and white photo of cow in field',
#   ['herd of sheep standing next to each other on dirt ground',
#    'crowded sheep of different colors stand in an enclosure',
#    'very large herd of sheep of all different colors',
#    'furry goats and other animals in crowded pen',
#    'close up of lot of animals with fence']],
#  '000000284445': ['group of people standing next to each other in front of building',
#   ['group of people crossing street next to bend traffic light',
#    'very crowded sidewalk with crooked light pole',
#    'light post leans towards crowd on busy city street',
#    'pedestrians walking on sidewalk by badly tipped traffic light',
#    'number of people walking on side walk']],
#  '000000094326': ['statue of black and white photo of park bench',
#   ['white statue holding open newspaper while sitting on bench',
#    'person reading paper on park bench',
#    'the statue on the bench is reading large newspaper',
#    'statue of man reading on park bench',
#    'sculpture of man reading newspaper sitting at bench']],
#  '000000261712': ['group of giraffes standing next to each other in field',
#   ['two giraffes at the zoo during the day',
#    'two giraffes wander the open park in the same direction',
#    'two giraffe standing next to each other on dirt road next to grass field',
#    'two giraffe standing on dirt near flowering trees',
#    'two giraffes standing on dirt path in fenced in area with trees and green grass surrounding them']],
#  '000000105912': ['red fire hydrant sitting on the side of road',
#   ['red fire hydrant sitting on sidewalk',
#    'red fire hydrant on red bricked sidewalk',
#    'hydrant is shown on the side of the walkway',
#    'woman is standig on the pavement looking',
#    'red fire hydrant is on the brick sidewalk']],
#  '000000046497': ['woman in bikini sitting on top of boat',
#   ['two little girls sitting on the side of white boat',
#    'two girls sitting on device on side of boat',
#    'two girls are sitting on the edge of boat looking at the water',
#    'little girls are on the edge of boat',
#    'children are sitting on the side of the boat in the water']],
#  '000000306136': ['double decker bus driving down street next to tall buildings',
#   ['bus stopped in front of building with the apple logo on it',
#    'an apple logo burns bright over city bus',
#    'an apple building and white bus and people',
#    'bus parked near an apple sign during the night',
#    'bus parked outside and below an illuminated apple sign']],
#  '000000101780': ['couple of giraffe standing next to each other',
#   ['giraffe eating some leaves from tree at the zoo',
#    'giraffe standing under large tree in an enclosed area',
#    'group of animals that are by tree',
#    'zoo giraffe enjoys treat from hanging basket',
#    'giraffe reaching for tree branch on sandy zoo lot']],
#  '000000023230': ['the swans are swimming in the water by the lake',
#   ['family of swans swimming on top of lake',
#    'group of geese swimming in water near wooded area',
#    'four geese floating in the middle of river',
#    'ducks in body of water with trees in the background',
#    'gaggle of geese swim in body of water']],
#  '000000027932': ['little boy that is standing in the grass',
#   ['catchers mitt sitting inside of blue baseball hat',
#    'baseball cap and catchers mitt sitting on the ground',
#    'closeup of baseball glove and black ball hat',
#    'close up of baseball glove on the ground with hat',
#    'baseball hat on top of baseball glove in the sand']],
#  '000000080666': ['black and white cat sitting on top of wooden bench',
#   ['cat sitting on top of bench in field',
#    'cat sitting on bench in front of house',
#    'close up of cat sitting on bench',
#    'white and brown cat sitting alone on bench',
#    'cat sitting on bench in front of building']],
#  ...}

# %% [markdown]
# ## Greedy Search version

# %%
let it fail
## GREEDY SEARCH   GREEDY SEARCH    GREEDY SEARCH     GREEDY SEARCH
## use the encodings and get inferences - GREEDY SEARCH
comparison_dict = {}  ## key will be the image name, values will be inference caption and the cleaned descriptions
total_to_infer = len(img_encodings_test)
i = 0
for key_img, img_pre_encoding_from_pkl in img_encodings_test.items():
    if i % 50 == 0:
        print(f"Processing {i+1} of {total_to_infer}")
    ## get the inference caption
    predicted_caption = do_inference_one_image_on_encoding_GREEDY(img_pre_encoding_from_pkl, MAX_LENGTH_CAPTION, reloaded_RNN_decoder, wordtoix, ixtoword)
    if i % 100 == 0:
        print(f"{i+1} cap =\n{predicted_caption}")
    ## strip off the startseq and endseq - note that startseq is ALWAYS present as the first word, but the endseq MAY NOT ALWAYS be at the end
    predicted_caption = predicted_caption.split(' ')
    if predicted_caption[-1] == 'endseq':
        predicted_caption = ' '.join(predicted_caption[1:-1]) ## remove both ends
    else:
        predicted_caption = ' '.join(predicted_caption[1:])   ## remove only startseq
    ## update the comparison dict
    comparison_dict.update( { key_img : [predicted_caption , descriptions_test[key_img] ] } )
    i += 1
print(f"Done")
# Out:
# Processing 1 of 5000
# 1 cap =
# startseq motorcycle parked on the side of the road endseq
# Processing 51 of 5000
# Processing 101 of 5000
# 101 cap =
# startseq large clock tower with clock on it endseq
# Processing 151 of 5000
# Processing 201 of 5000
# 201 cap =
# startseq kitchen with wooden floors and wooden table endseq
# Processing 251 of 5000
# Processing 301 of 5000
# 301 cap =
# startseq an old stove with an open door and the door open endseq
# Processing 351 of 5000
# Processing 401 of 5000
# 401 cap =
# startseq plane flying through the sky with clouds in the background endseq
# Processing 451 of 5000
# Processing 501 of 5000
# 501 cap =
# startseq man in kitchen with his hands up endseq
# Processing 551 of 5000
# Processing 601 of 5000
# 601 cap =
# startseq dog is sitting on the floor with frisbee endseq
# Processing 651 of 5000
# Processing 701 of 5000
# 701 cap =
# startseq bathroom sink with mirror and mirror endseq
# Processing 751 of 5000
# Processing 801 of 5000
# 801 cap =
# startseq small airplane is parked on the runway endseq
# Processing 851 of 5000
# Processing 901 of 5000
# 901 cap =
# startseq giraffe standing in field with trees in the background endseq
# Processing 951 of 5000
# Processing 1001 of 5000
# 1001 cap =
# startseq fire hydrant is sitting on the side of the road endseq
# Processing 1051 of 5000
# Processing 1101 of 5000
# 1101 cap =
# startseq red and white bus is parked in front of building endseq
# Processing 1151 of 5000
# Processing 1201 of 5000
# 1201 cap =
# startseq bird is standing on the edge of the water endseq
# Processing 1251 of 5000
# Processing 1301 of 5000
# 1301 cap =
# startseq group of people standing around with their skateboards endseq
# Processing 1351 of 5000
# Processing 1401 of 5000
# 1401 cap =
# startseq bench sitting in front of tree endseq
# Processing 1451 of 5000
# Processing 1501 of 5000
# 1501 cap =
# startseq man sitting on bench with dog endseq
# Processing 1551 of 5000
# Processing 1601 of 5000
# 1601 cap =
# startseq two sheep are standing in the grass endseq
# Processing 1651 of 5000
# Processing 1701 of 5000
# 1701 cap =
# startseq boat is sitting on the water near the water endseq
# Processing 1751 of 5000
# Processing 1801 of 5000
# 1801 cap =
# startseq train is parked on the side of the road endseq
# Processing 1851 of 5000
# Processing 1901 of 5000
# 1901 cap =
# startseq bear is standing in the middle of the road endseq
# Processing 1951 of 5000
# Processing 2001 of 5000
# 2001 cap =
# startseq cat is sitting on the floor looking at the camera endseq
# Processing 2051 of 5000
# Processing 2101 of 5000
# 2101 cap =
# startseq man standing on snow covered slope next to red truck endseq
# Processing 2151 of 5000
# Processing 2201 of 5000
# 2201 cap =
# startseq two men playing frisbee in field endseq
# Processing 2251 of 5000
# Processing 2301 of 5000
# 2301 cap =
# startseq man with hat and hat on endseq
# Processing 2351 of 5000
# Processing 2401 of 5000
# 2401 cap =
# startseq truck with graffiti on it is parked in the grass endseq
# Processing 2451 of 5000
# Processing 2501 of 5000
# 2501 cap =
# startseq bowl of food with broccoli and meat endseq
# Processing 2551 of 5000
# Processing 2601 of 5000
# 2601 cap =
# startseq dog is sitting on bench in front of the building endseq
# Processing 2651 of 5000
# Processing 2701 of 5000
# 2701 cap =
# startseq man riding skateboard down the side of ramp endseq
# Processing 2751 of 5000
# Processing 2801 of 5000
# 2801 cap =
# startseq baseball player swinging bat at ball endseq
# Processing 2851 of 5000
# Processing 2901 of 5000
# 2901 cap =
# startseq baseball player swinging bat on field endseq
# Processing 2951 of 5000
# Processing 3001 of 5000
# 3001 cap =
# startseq fruit stand with lots of vegetables and vegetables endseq
# Processing 3051 of 5000
# Processing 3101 of 5000
# 3101 cap =
# startseq woman walking down street with an umbrella endseq
# Processing 3151 of 5000
# Processing 3201 of 5000
# 3201 cap =
# startseq dog is standing on the grass with frisbee endseq
# Processing 3251 of 5000
# Processing 3301 of 5000
# 3301 cap =
# startseq living room with television and couch endseq
# Processing 3351 of 5000
# Processing 3401 of 5000
# 3401 cap =
# startseq man is holding surfboard on the beach endseq
# Processing 3451 of 5000
# Processing 3501 of 5000
# 3501 cap =
# startseq man riding skis down snow covered slope endseq
# Processing 3551 of 5000
# Processing 3601 of 5000
# 3601 cap =
# startseq man with hat and hat holding an umbrella endseq
# Processing 3651 of 5000
# Processing 3701 of 5000
# 3701 cap =
# startseq man and woman are standing in the grass endseq
# Processing 3751 of 5000
# Processing 3801 of 5000
# 3801 cap =
# startseq man in suit is holding up doughnut endseq
# Processing 3851 of 5000
# Processing 3901 of 5000
# 3901 cap =
# startseq cake with candles on top of it endseq
# Processing 3951 of 5000
# Processing 4001 of 5000
# 4001 cap =
# startseq woman laying on bed with her arms crossed endseq
# Processing 4051 of 5000
# Processing 4101 of 5000
# 4101 cap =
# startseq man is playing tennis on the court endseq
# Processing 4151 of 5000
# Processing 4201 of 5000
# 4201 cap =
# startseq an old cell phone sitting on table endseq
# Processing 4251 of 5000
# Processing 4301 of 5000
# 4301 cap =
# startseq man playing tennis on tennis court endseq
# Processing 4351 of 5000
# Processing 4401 of 5000
# 4401 cap =
# startseq an image of an old fashioned cake with candles on it endseq
# Processing 4451 of 5000
# Processing 4501 of 5000
# 4501 cap =
# startseq woman is standing on beach with kite endseq
# Processing 4551 of 5000
# Processing 4601 of 5000
# 4601 cap =
# startseq kitchen with sink and refrigerator endseq
# Processing 4651 of 5000
# Processing 4701 of 5000
# 4701 cap =
# startseq an old fashioned computer keyboard sitting on top of table endseq
# Processing 4751 of 5000
# Processing 4801 of 5000
# 4801 cap =
# startseq man in suit and tie talking on cell phone endseq
# Processing 4851 of 5000
# Processing 4901 of 5000
# 4901 cap =
# startseq vase with flowers in it sitting on table endseq
# Processing 4951 of 5000
# Done

# %%
## see a few random entries
dict(list(comparison_dict.items())[:15])
# Out:
# {'000000179765': ['motorcycle parked on the side of the road',
#   ['black honda motorcycle parked in front of garage',
#    'honda motorcycle parked in grass driveway',
#    'black honda motorcycle with dark burgundy seat',
#    'ma motorcycle parked on the gravel in front of garage',
#    'motorcycle with its brake extended standing outside']],
#  '000000190236': ['desk with computer and computer on it',
#   ['an office cubicle with four different types of computers',
#    'the home office space seems to be very cluttered',
#    'an office with desk computer and chair and laptop',
#    'office setting with lot of computer screens',
#    'desk and chair in an office cubicle']],
#  '000000331352': ['toilet with white lid and sink',
#   ['small closed toilet in cramped space',
#    'tan toilet and sink combination in small room',
#    'this is an advanced toilet with sink and control panel',
#    'close up picture of toilet with fountain',
#    'off white toilet with faucet and controls']],
#  '000000517069': ['man is walking down the street with his skateboard',
#   ['two women waiting at bench next to street',
#    'woman sitting on bench and woman standing waiting for the bus',
#    'woman sitting on bench in the middle of the city',
#    'woman sitting on bench and woman standing behind the bench at bus stop',
#    'woman and another woman waiting at stop']],
#  '000000182417': ['plate of food with fork and fork',
#   ['beautiful dessert waiting to be shared by two people',
#    'there is piece of cake on plate with decorations on it',
#    'creamy cheesecake dessert with whip cream and caramel',
#    'an extravagant dessert on plate overlooking the water',
#    'this is picture of an extremely fancy desert']],
#  '000000046378': ['cat is standing on the ground with its head on the ground',
#   ['cat eating bird it has caught',
#    'white cat caught bird outside on patio',
#    'grey house cat devours song bird on door step',
#    'long haired cat eating dead bird',
#    'cat eating dead bird on the ground']],
#  '000000093437': ['man in black shirt and tie holding up hotdog',
#   ['shot of an elderly man inside kitchen',
#    'an old man is wearing an odd hat',
#    'an older man is wearing funny hat in his dining room',
#    'man in jacket and hat looks at the camera',
#    'an old man standing in kitchen posing for picture']],
#  '000000172330': ['dog is sitting on the hood of car',
#   ['cat in between two cars in parking lot',
#    'cat stands between two parked cars on grassy sidewalk',
#    'cat at attention between two parked cars',
#    'grey and white cat watches from between parked cars',
#    'grey and white cat standing in the grass in parking lot']],
#  '000000472678': ['computer desk with computer monitor and keyboard',
#   ['an office cubicle with multiple computers in it',
#    'an office desk with two flat panel monitors',
#    'an office desk with two computer screens books diagrams and phone on it',
#    'two computer monitors are placed beside each other on desk',
#    'desk with two monitors depicting security cameras']],
#  '000000314251': ['man riding bike down street',
#   ['parade of motorcycles is going through group of tall trees',
#    'group of motorcyclists drive down tree lined street',
#    'group of motorcycles down long street filled with trees on either side',
#    'group of people riding mopeds through park',
#    'group of scooters rides down street']],
#  '000000223747': ['man laying on bed with his dog',
#   ['man sleeping with his cat next to him',
#    'young man and his cute cat enjoy nap together',
#    'man is sleeping with his head on pillow',
#    'man sleeping in his bedroom next to cat',
#    'man sleeping next to cat on bed']],
#  '000000109976': ['kitchen with stove sink and refrigerator',
#   ['an all white kitchen with an electric stovetop',
#    'white stove sits between two small counter tops',
#    'close up of white kitchen setup with coffee maker on counter',
#    'white stove and cabinet inside kitchen',
#    'this is small kitchen with white cabinets and appliances']],
#  '000000012667': ['woman is holding pair of scissors',
#   ['the telephone has banana where the receiver should be',
#    'banana replacing the phone on an answering machine',
#    'phone with banana where the receiver should be',
#    'telephone has it receiver replaced with banana',
#    'banana placed on phone on table']],
#  '000000482917': ['dog laying on the floor next to television',
#   ['dog sitting between its masters feet on footstool watching tv',
#    'dog between the feet of person looking at tv',
#    'dog and person are watching television together',
#    'person is sitting with their dog watching tv',
#    'man relaxing at home watching television with his dog']],
#  '000000534605': ['group of people riding motorcycles down street',
#   ['man in motorcycle leathers standing in front of group of bikes',
#    'bikers dressed in their gear standing near their motorcycles',
#    'group of men stand next to their bicycles',
#    'three men standing around their motorcycles in parking lot',
#    'group of three motorcyclists standing in front of their motorcycles']]}

# %% [markdown]
# ## VERIFY WHERE TO PICKLE THE COMPARISON

# %%
OPDIR = r'/home/rohit/PyWDUbuntu/thesis/'

# %%
OPDIR
# Out:
# '/home/rohit/PyWDUbuntu/thesis/'

# %%
COMPARISON_DICT_PICKLE_FILE = r'ImgCap_Run3_TestSet_DescCap_Comparison_BeamWidth5_WtEp18_1.pkl'

# %%
print(f"Picle destination=\n{OPDIR + COMPARISON_DICT_PICKLE_FILE}")
# Out:
# Picle destination=
# /home/rohit/PyWDUbuntu/thesis/ImgCap_Run3_TestSet_DescCap_Comparison_BeamWidth5_WtEp18_1.pkl

# %%
os.path.exists(OPDIR + COMPARISON_DICT_PICKLE_FILE)
# Out:
# False

# %%
## pickle it
if os.path.exists(OPDIR + COMPARISON_DICT_PICKLE_FILE):
    print(f"File already exists - DID NOT PICKLE")
else:
    with open(OPDIR + COMPARISON_DICT_PICKLE_FILE, 'wb') as handle:
      pickle.dump(comparison_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print(f"Success, pickled to:\n{OPDIR + COMPARISON_DICT_PICKLE_FILE}")
# Out:
# Success, pickled to:
# /home/rohit/PyWDUbuntu/thesis/ImgCap_Run3_TestSet_DescCap_Comparison_BeamWidth5_WtEp18_1.pkl

# %%
## from original data - without reloading from pickle - for reference when reloading later
comparison_dict['000000179765']
# Out:
# ['motorcycle is parked on the side of the road',
#  ['black honda motorcycle parked in front of garage',
#   'honda motorcycle parked in grass driveway',
#   'black honda motorcycle with dark burgundy seat',
#   'ma motorcycle parked on the gravel in front of garage',
#   'motorcycle with its brake extended standing outside']]

# %% [markdown]
# # CALCULATE BLEU SCORE USING NLTK

# %% [markdown]
# # SUPER IMPORTANT - CHANGE CONDA ENV FIRST
# ## DO NOT USE               ce7comb1
# ## CHANGE TO                ce6idelements1

# %%
import nltk.translate.bleu_score as nltk_bleu
import pickle
import pandas as pd
import numpy as np
import os

# %%
OPDIR = r'/home/rohit/PyWDUbuntu/thesis/'
OPDIR
# Out:
# '/home/rohit/PyWDUbuntu/thesis/'

# %%
COMPARISON_DICT_PICKLE_FILE = r'ImgCap_Run3_TestSet_DescCap_Comparison_BeamWidth5_WtEp18_1.pkl'

# %%
print(f"Picle source=\n{OPDIR + COMPARISON_DICT_PICKLE_FILE}")
print(f"\nExists = {os.path.exists(OPDIR + COMPARISON_DICT_PICKLE_FILE)}\t\tIs File = {os.path.isfile(OPDIR + COMPARISON_DICT_PICKLE_FILE)}")
# Out:
# Picle source=
# /home/rohit/PyWDUbuntu/thesis/ImgCap_Run3_TestSet_DescCap_Comparison_BeamWidth5_WtEp18_1.pkl
#
# Exists = True		Is File = True

# %% [markdown]
# ## Reload from pickled file

# %%
with open(OPDIR + COMPARISON_DICT_PICKLE_FILE, 'rb') as handle:
  comparison_dict_reload = pickle.load(handle)
print(f"Reloaded from picle file:\n{OPDIR + COMPARISON_DICT_PICKLE_FILE}")
# Out:
# Reloaded from picle file:
# /home/rohit/PyWDUbuntu/thesis/ImgCap_Run3_TestSet_DescCap_Comparison_BeamWidth5_WtEp18_1.pkl

# %%
## compare reloaded info with - for reference displayed from original data
comparison_dict_reload['000000179765']
# Out:
# ['motorcycle is parked on the side of the road',
#  ['black honda motorcycle parked in front of garage',
#   'honda motorcycle parked in grass driveway',
#   'black honda motorcycle with dark burgundy seat',
#   'ma motorcycle parked on the gravel in front of garage',
#   'motorcycle with its brake extended standing outside']]

# %% [markdown]
# ## Bleu scores with NLTK
#
# ### Link: https://ariepratama.github.io/Introduction-to-BLEU-in-python/

# %%
## see a few random entries
dict(list(comparison_dict_reload.items())[:5])
# Out:
# {'000000179765': ['motorcycle is parked on the side of the road',
#   ['black honda motorcycle parked in front of garage',
#    'honda motorcycle parked in grass driveway',
#    'black honda motorcycle with dark burgundy seat',
#    'ma motorcycle parked on the gravel in front of garage',
#    'motorcycle with its brake extended standing outside']],
#  '000000190236': ['desk with computer monitor and monitor',
#   ['an office cubicle with four different types of computers',
#    'the home office space seems to be very cluttered',
#    'an office with desk computer and chair and laptop',
#    'office setting with lot of computer screens',
#    'desk and chair in an office cubicle']],
#  '000000331352': ['white toilet sitting next to bath tub',
#   ['small closed toilet in cramped space',
#    'tan toilet and sink combination in small room',
#    'this is an advanced toilet with sink and control panel',
#    'close up picture of toilet with fountain',
#    'off white toilet with faucet and controls']],
#  '000000517069': ['man and woman sitting on park bench',
#   ['two women waiting at bench next to street',
#    'woman sitting on bench and woman standing waiting for the bus',
#    'woman sitting on bench in the middle of the city',
#    'woman sitting on bench and woman standing behind the bench at bus stop',
#    'woman and another woman waiting at stop']],
#  '000000182417': ['white plate topped with plates of food',
#   ['beautiful dessert waiting to be shared by two people',
#    'there is piece of cake on plate with decorations on it',
#    'creamy cheesecake dessert with whip cream and caramel',
#    'an extravagant dessert on plate overlooking the water',
#    'this is picture of an extremely fancy desert']]}

# %%
## see a few random bleu scores
i = 0
for k, v in comparison_dict_reload.items():
    i += 1
    #print('BLEU score: {}'.format(bleu.sentence_bleu(reference, translation)))
    print(f"Caption {i} :: {k + '.jpg'} :: Bleu score = {nltk_bleu.sentence_bleu(v[1], v[0])}")
    if i > 3:
        break
# Out:
# Caption 1 :: 000000179765.jpg :: Bleu score = 0.6840733593314962
# Caption 2 :: 000000190236.jpg :: Bleu score = 0.6105914015122715
# Caption 3 :: 000000331352.jpg :: Bleu score = 0.49175119501736847
# Caption 4 :: 000000517069.jpg :: Bleu score = 0.7609546880687025

# %%
## calculate bleu scores for all the 5k images
bscores_all = list()
i = 0
for k, v in comparison_dict_reload.items():
    bscore = nltk_bleu.sentence_bleu(v[1], v[0])
    bscores_all.append([k, v[0], bscore])
    i += 1
print(f"Processed {i} inputs")
# Out:
# /home/rohit/anaconda3/envs/ce6idelements1/lib/python3.7/site-packages/nltk/translate/bleu_score.py:516: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Processed 5000 inputs

# %%
len(bscores_all)
# Out:
# 5000

# %%
## see a few random entries
bscores_all[:10]
# Out:
# [['000000179765',
#   'motorcycle is parked on the side of the road',
#   0.6840733593314962],
#  ['000000190236',
#   'desk with computer monitor and monitor',
#   0.6105914015122715],
#  ['000000331352',
#   'white toilet sitting next to bath tub',
#   0.49175119501736847],
#  ['000000517069', 'man and woman sitting on park bench', 0.7609546880687025],
#  ['000000182417',
#   'white plate topped with plates of food',
#   0.45504753033788703],
#  ['000000046378',
#   'black and white photo of two sheep in field',
#   0.21300658281177043],
#  ['000000093437',
#   'the man is holding hot dog in his mouth',
#   0.6343895813329494],
#  ['000000172330',
#   'black and white photo of cat on motorcycle',
#   0.45073768306250617],
#  ['000000472678',
#   'desktop computer sitting on top of wooden desk',
#   0.5555577534996655],
#  ['000000314251',
#   'group of people riding on the back of red motorcycle',
#   0.7882191500985157]]

# %%
dfbs = pd.DataFrame(bscores_all, columns=['img', 'infcap', 'bsnltk'])
dfbs.sort_values(by=['bsnltk'], inplace = True)

# %%
dfbs.head()
# Out:
#                img                                             infcap  \
# 2660  000000216277                close up of person holding doughnut
# 3159  000000251537               an image of bunch of bananas in bowl
# 3243  000000245311  table topped with lots of different types of food
# 1556  000000494188  black and white photo of an old black and whit...
# 2180  000000205289  black and white photo of an old black and whit...
#
#             bsnltk
# 2660  3.313386e-78
# 3159  4.178745e-78
# 3243  5.359796e-78
# 1556  7.443001e-02
# 2180  8.771971e-02

# %%
dfbs.tail()
# Out:
#                img                                          infcap  bsnltk
# 1412  000000373705    red fire hydrant sitting on the side of road     1.0
# 2820  000000559707         close up of plate of food with broccoli     1.0
# 1572  000000001584  red double decker bus driving down city street     1.0
# 3540  000000199442             man riding wave on top of surfboard     1.0
# 3593  000000515350             man riding wave on top of surfboard     1.0

# %%
bs_max = float(dfbs[['bsnltk']].max(axis=0))
bs_med = float(dfbs[['bsnltk']].median(axis=0))
bs_min = float(dfbs[['bsnltk']].min(axis=0))
bs_avg = float(dfbs[['bsnltk']].mean(axis=0))
bs_std = float(dfbs[['bsnltk']].std(axis=0))
print(f"\t\tBlue Scores:")
print(f"\nMax = {bs_max}\nMedian = {bs_med}\nMin = {bs_min}\nAverage = {bs_avg}\nStd Dev = {bs_std}")
# Out:
# 		Blue Scores:
#
# Max = 1.0
# Median = 0.6269845096151256
# Min = 3.3133861061454425e-78
# Average = 0.6235485829610334
# Std Dev = 0.16169924891203755

# %%
len(dfbs[dfbs['bsnltk'] > 0.95])
# Out:
# 94

# %%
## freq distribution
total_data = len(dfbs)
step = np.linspace(0,1,21)[1] - np.linspace(0,1,21)[0]
prev_running = 0
for val in np.linspace(0,1,21)[1:]:   ## do not want to start from value 0.0 but from 0.05 till 1.0
    wintop = round(float(val), 2)
    winbot = wintop-step
    print(f"{winbot:.2f} to {wintop:.2f} : ", end='')
    cnt_running = len(dfbs[ dfbs['bsnltk'] < wintop ] )
    cnt_this_window = cnt_running - prev_running
    print(f"cnt= {cnt_this_window: <6} ", end='')
    print(f"cntCum= {cnt_running: <7}", end='')
    print(f"relFreq= {cnt_this_window/total_data: <7.2f}", end='')
    print(f"cumFreq= {cnt_running/total_data: <7.2f}")
    prev_running = cnt_running
# Out:
# 0.00 to 0.05 : cnt= 3      cntCum= 3      relFreq= 0.00   cumFreq= 0.00
# 0.05 to 0.10 : cnt= 3      cntCum= 6      relFreq= 0.00   cumFreq= 0.00
# 0.10 to 0.15 : cnt= 2      cntCum= 8      relFreq= 0.00   cumFreq= 0.00
# 0.15 to 0.20 : cnt= 12     cntCum= 20     relFreq= 0.00   cumFreq= 0.00
# 0.20 to 0.25 : cnt= 42     cntCum= 62     relFreq= 0.01   cumFreq= 0.01
# 0.25 to 0.30 : cnt= 70     cntCum= 132    relFreq= 0.01   cumFreq= 0.03
# 0.30 to 0.35 : cnt= 126    cntCum= 258    relFreq= 0.03   cumFreq= 0.05
# 0.35 to 0.40 : cnt= 197    cntCum= 455    relFreq= 0.04   cumFreq= 0.09
# 0.40 to 0.45 : cnt= 266    cntCum= 721    relFreq= 0.05   cumFreq= 0.14
# 0.45 to 0.50 : cnt= 395    cntCum= 1116   relFreq= 0.08   cumFreq= 0.22
# 0.50 to 0.55 : cnt= 467    cntCum= 1583   relFreq= 0.09   cumFreq= 0.32
# 0.55 to 0.60 : cnt= 564    cntCum= 2147   relFreq= 0.11   cumFreq= 0.43
# 0.60 to 0.65 : cnt= 628    cntCum= 2775   relFreq= 0.13   cumFreq= 0.56
# 0.65 to 0.70 : cnt= 573    cntCum= 3348   relFreq= 0.11   cumFreq= 0.67
# 0.70 to 0.75 : cnt= 540    cntCum= 3888   relFreq= 0.11   cumFreq= 0.78
# 0.75 to 0.80 : cnt= 424    cntCum= 4312   relFreq= 0.08   cumFreq= 0.86
# 0.80 to 0.85 : cnt= 295    cntCum= 4607   relFreq= 0.06   cumFreq= 0.92
# 0.85 to 0.90 : cnt= 200    cntCum= 4807   relFreq= 0.04   cumFreq= 0.96
# 0.90 to 0.95 : cnt= 99     cntCum= 4906   relFreq= 0.02   cumFreq= 0.98
# 0.95 to 1.00 : cnt= 60     cntCum= 4966   relFreq= 0.01   cumFreq= 0.99

# %%
step = np.linspace(0,1,21)[1] - np.linspace(0,1,21)[0]
step
# Out:
# 0.05

# %%
np.linspace(0,1,21)
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])

# %%
np.linspace(0,1,21)[4:]
# Out:
# array([0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55, 0.6 , 0.65, 0.7 ,
#        0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])
